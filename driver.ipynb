# %% [markdown]
# # Riot Games API Set-Up
# ### Python Environment Libraries:
# pandas, numpy, requests, json

# %%
import pandas as pd
import requests
import json

# %% [markdown]
# ### API KEY MUST BE UPDATED AFTER EVERY 24 HOURS

# %%
API_KEY = "RGAPI-943f21fe-d765-4959-9db9-71565933aec3"

# %% [markdown]
# ### Hardcoded Player Information (TODO)

# %%
encryptedAccountId = "x1jjbMOl33kYCZs0y5HfCmvPwQD-Ai-QubugHIx5kEUtiFI"
encryptedSummonerId = "HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0"
puuid = "G-7wmI2szoObELtiJno5R3xgCbYsJSPnugX8twyJBNJEfYqeNn_JlKVLpePqQo2NSIdQ_g06GJuLeg"
ign_tag = "Wargoblin77/NA1"

# %% [markdown]
# ### URL Components from APIs (TODO)
# List of APIs: https://developer.riotgames.com/apis

# %%
url = "https://na1.api.riotgames.com/"
# SUMMONER-V4 API
summ_request = "lol/summoner/v4/summoners/by-account/"
# CHAMPION-MASTERY-V4 API
champ_mastery_request = "lol/champion-mastery/v4/champion-masteries/by-summoner/"
# ACCOUNT-V1 API
account_request = "riot/account/v1/accounts/by-riot-id/"
# MATCH-V5 API (LoL)
match_request = "/lol/match/v5/matches/by-puuid/" + puuid + "/ids?start=0&count=50&api_key=" + API_KEY

# %% [markdown]
# # Requests Data Scratch (Testing)

# %%
r1 = requests.get(url + champ_mastery_request + encryptedSummonerId + '?api_key=' + API_KEY)
r1.json()
# Out:
# [{'championId': 37,
#   'championLevel': 7,
#   'championPoints': 146848,
#   'lastPlayTime': 1634532342000,
#   'championPointsSinceLastLevel': 125248,
#   'championPointsUntilNextLevel': 0,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0'},
#  {'championId': 78,
#   'championLevel': 6,
#   'championPoints': 106276,
#   'lastPlayTime': 1661135966000,
#   'championPointsSinceLastLevel': 84676,
#   'championPointsUntilNextLevel': 0,
#   'chestGranted': False,
#   'tokensEarned': 2,
#   'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0'},
#  {'championId': 32,
#   'championLevel': 7,
#   'championPoints': 79674,
#   'lastPlayTime': 1674376844000,
#   'championPointsSinceLastLevel': 58074,
#   'championPointsUntilNextLevel': 0,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0'},
#  {'championId': 412,
#   'championLevel': 6,
#   'championPoints': 54192,
#   'lastPlayTime': 1676172169000,
#   'championPointsSinceLastLevel': 32592,
#   'championPointsUntilNextLevel': 0,
#   'chestGranted': True,
#   'tokensEarned': 0,
#   'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0'},
#  {'championId': 39,
#   'championLevel': 6,
#   'championPoints': 45125,
#   'lastPlayTime': 1653449637000,
#   'championPointsSinceLastLevel': 23525,
#   'championPointsUntilNextLevel': 0,
#   'chestGranted': False,
#   'tokensEarned': 1,
#   'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0'},
#  {'championId': 89,
#   'championLevel': 6,
#   'championPoints': 39262,
#   'lastPlayTime': 1673768795000,
#   'championPointsSinceLastLevel': 17662,
#   'championPointsUntilNextLevel': 0,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0'},
#  {'championId': 40,
#   'championLevel': 6,
#   'championPoints': 34156,
#   'lastPlayTime': 1674379035000,
#   'championPointsSinceLastLevel': 12556,
#   'championPointsUntilNextLevel': 0,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0'},
#  {'championId': 22,
#   'championLevel': 5,
#   'championPoints': 32734,
#   'lastPlayTime': 1619856173000,
#   'championPointsSinceLastLevel': 11134,
#   'championPointsUntilNextLevel': 0,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0'},
#  {'championId': 16,
#   'championLevel': 6,
#   'championPoints': 30153,
#   'lastPlayTime': 1573877009000,
#   'championPointsSinceLastLevel': 8553,
#   'championPointsUntilNextLevel': 0,
#   'chestGranted': False,
#   'tokensEarned': 1,
#   'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0'},
#  {'championId': 19,
#   'championLevel': 5,
#   'championPoints': 28424,
#   'lastPlayTime': 1599359199000,
#   'championPointsSinceLastLevel': 6824,
#   'championPointsUntilNextLevel': 0,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0'},
#  {'championId': 50,
#   'championLevel': 5,
#   'championPoints': 26621,
#   'lastPlayTime': 1663657510000,
#   'championPointsSinceLastLevel': 5021,
#   'championPointsUntilNextLevel': 0,
#   'chestGranted': False,
#   'tokensEarned': 1,
#   'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0'},
#  {'championId': 12,
#   'championLevel': 5,
#   'championPoints': 26472,
#   'lastPlayTime': 1673767381000,
#   'championPointsSinceLastLevel': 4872,
#   'championPointsUntilNextLevel': 0,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0'},
#  {'championId': 131,
#   'championLevel': 5,
#   'championPoints': 24607,
#   'lastPlayTime': 1674021818000,
#   'championPointsSinceLastLevel': 3007,
#   'championPointsUntilNextLevel': 0,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0'},
#  {'championId': 1,
#   'championLevel': 5,
#   'championPoints': 23001,
#   'lastPlayTime': 1575518323000,
#   'championPointsSinceLastLevel': 1401,
#   'championPointsUntilNextLevel': 0,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0'},
#  {'championId': 53,
#   'championLevel': 4,
#   'championPoints': 21250,
#   'lastPlayTime': 1669346165000,
#   'championPointsSinceLastLevel': 8650,
#   'championPointsUntilNextLevel': 350,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0'},
#  {'championId': 33,
#   'championLevel': 4,
#   'championPoints': 20342,
#   'lastPlayTime': 1633925445000,
#   'championPointsSinceLastLevel': 7742,
#   'championPointsUntilNextLevel': 1258,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0'},
#  {'championId': 111,
#   'championLevel': 4,
#   'championPoints': 18256,
#   'lastPlayTime': 1673776654000,
#   'championPointsSinceLastLevel': 5656,
#   'championPointsUntilNextLevel': 3344,
#   'chestGranted': True,
#   'tokensEarned': 0,
#   'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0'},
#  {'championId': 31,
#   'championLevel': 4,
#   'championPoints': 17663,
#   'lastPlayTime': 1663656131000,
#   'championPointsSinceLastLevel': 5063,
#   'championPointsUntilNextLevel': 3937,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0'},
#  {'championId': 17,
#   'championLevel': 4,
#   'championPoints': 16408,
#   'lastPlayTime': 1575351151000,
#   'championPointsSinceLastLevel': 3808,
#   'championPointsUntilNextLevel': 5192,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0'},
#  {'championId': 223,
#   'championLevel': 4,
#   'championPoints': 16079,
#   'lastPlayTime': 1673770304000,
#   'championPointsSinceLastLevel': 3479,
#   'championPointsUntilNextLevel': 5521,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0'},
#  {'championId': 15,
#   'championLevel': 4,
#   'championPoints': 15702,
#   'lastPlayTime': 1636172514000,
#   'championPointsSinceLastLevel': 3102,
#   'championPointsUntilNextLevel': 5898,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0'},
#  {'championId': 117,
#   'championLevel': 4,
#   'championPoints': 13604,
#   'lastPlayTime': 1659932851000,
#   'championPointsSinceLastLevel': 1004,
#   'championPointsUntilNextLevel': 7996,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0'},
#  {'championId': 27,
#   'championLevel': 4,
#   'championPoints': 13330,
#   'lastPlayTime': 1674381440000,
#   'championPointsSinceLastLevel': 730,
#   'championPointsUntilNextLevel': 8270,
#   'chestGranted': True,
#   'tokensEarned': 0,
#   'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0'},
#  {'championId': 86,
#   'championLevel': 4,
#   'championPoints': 12947,
#   'lastPlayTime': 1585522153000,
#   'championPointsSinceLastLevel': 347,
#   'championPointsUntilNextLevel': 8653,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0'},
#  {'championId': 11,
#   'championLevel': 3,
#   'championPoints': 11010,
#   'lastPlayTime': 1579061172000,
#   'championPointsSinceLastLevel': 5010,
#   'championPointsUntilNextLevel': 1590,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0'},
#  {'championId': 63,
#   'championLevel': 3,
#   'championPoints': 10867,
#   'lastPlayTime': 1653450725000,
#   'championPointsSinceLastLevel': 4867,
#   'championPointsUntilNextLevel': 1733,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0'},
#  {'championId': 43,
#   'championLevel': 3,
#   'championPoints': 10307,
#   'lastPlayTime': 1584508027000,
#   'championPointsSinceLastLevel': 4307,
#   'championPointsUntilNextLevel': 2293,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0'},
#  {'championId': 14,
#   'championLevel': 3,
#   'championPoints': 9059,
#   'lastPlayTime': 1660539692000,
#   'championPointsSinceLastLevel': 3059,
#   'championPointsUntilNextLevel': 3541,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0'},
#  {'championId': 25,
#   'championLevel': 3,
#   'championPoints': 8933,
#   'lastPlayTime': 1580022080000,
#   'championPointsSinceLastLevel': 2933,
#   'championPointsUntilNextLevel': 3667,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0'},
#  {'championId': 21,
#   'championLevel': 3,
#   'championPoints': 8822,
#   'lastPlayTime': 1626759699000,
#   'championPointsSinceLastLevel': 2822,
#   'championPointsUntilNextLevel': 3778,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0'},
#  {'championId': 102,
#   'championLevel': 3,
#   'championPoints': 8714,
#   'lastPlayTime': 1674024631000,
#   'championPointsSinceLastLevel': 2714,
#   'championPointsUntilNextLevel': 3886,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0'},
#  {'championId': 29,
#   'championLevel': 3,
#   'championPoints': 8479,
#   'lastPlayTime': 1592972060000,
#   'championPointsSinceLastLevel': 2479,
#   'championPointsUntilNextLevel': 4121,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0'},
#  {'championId': 92,
#   'championLevel': 3,
#   'championPoints': 8455,
#   'lastPlayTime': 1528697995000,
#   'championPointsSinceLastLevel': 2455,
#   'championPointsUntilNextLevel': 4145,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0'},
#  {'championId': 98,
#   'championLevel': 3,
#   'championPoints': 8320,
#   'lastPlayTime': 1660706428000,
#   'championPointsSinceLastLevel': 2320,
#   'championPointsUntilNextLevel': 4280,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0'},
#  {'championId': 201,
#   'championLevel': 3,
#   'championPoints': 8276,
#   'lastPlayTime': 1669177384000,
#   'championPointsSinceLastLevel': 2276,
#   'championPointsUntilNextLevel': 4324,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0'},
#  {'championId': 38,
#   'championLevel': 3,
#   'championPoints': 7970,
#   'lastPlayTime': 1576211253000,
#   'championPointsSinceLastLevel': 1970,
#   'championPointsUntilNextLevel': 4630,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0'},
#  {'championId': 13,
#   'championLevel': 3,
#   'championPoints': 7944,
#   'lastPlayTime': 1526759527000,
#   'championPointsSinceLastLevel': 1944,
#   'championPointsUntilNextLevel': 4656,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0'},
#  {'championId': 36,
#   'championLevel': 3,
#   'championPoints': 7285,
#   'lastPlayTime': 1661144692000,
#   'championPointsSinceLastLevel': 1285,
#   'championPointsUntilNextLevel': 5315,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0'},
#  {'championId': 81,
#   'championLevel': 3,
#   'championPoints': 6837,
#   'lastPlayTime': 1674023242000,
#   'championPointsSinceLastLevel': 837,
#   'championPointsUntilNextLevel': 5763,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0'},
#  {'championId': 5,
#   'championLevel': 3,
#   'championPoints': 6520,
#   'lastPlayTime': 1624341937000,
#   'championPointsSinceLastLevel': 520,
#   'championPointsUntilNextLevel': 6080,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0'},
#  {'championId': 75,
#   'championLevel': 3,
#   'championPoints': 6357,
#   'lastPlayTime': 1575774128000,
#   'championPointsSinceLastLevel': 357,
#   'championPointsUntilNextLevel': 6243,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0'},
#  {'championId': 497,
#   'championLevel': 3,
#   'championPoints': 6026,
#   'lastPlayTime': 1582689174000,
#   'championPointsSinceLastLevel': 26,
#   'championPointsUntilNextLevel': 6574,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0'},
#  {'championId': 126,
#   'championLevel': 2,
#   'championPoints': 5270,
#   'lastPlayTime': 1528400576000,
#   'championPointsSinceLastLevel': 3470,
#   'championPointsUntilNextLevel': 730,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0'},
#  {'championId': 59,
#   'championLevel': 2,
#   'championPoints': 5223,
#   'lastPlayTime': 1581913213000,
#   'championPointsSinceLastLevel': 3423,
#   'championPointsUntilNextLevel': 777,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0'},
#  {'championId': 150,
#   'championLevel': 2,
#   'championPoints': 4732,
#   'lastPlayTime': 1526534877000,
#   'championPointsSinceLastLevel': 2932,
#   'championPointsUntilNextLevel': 1268,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0'},
#  {'championId': 10,
#   'championLevel': 2,
#   'championPoints': 4719,
#   'lastPlayTime': 1537821302000,
#   'championPointsSinceLastLevel': 2919,
#   'championPointsUntilNextLevel': 1281,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0'},
#  {'championId': 45,
#   'championLevel': 2,
#   'championPoints': 4683,
#   'lastPlayTime': 1673773240000,
#   'championPointsSinceLastLevel': 2883,
#   'championPointsUntilNextLevel': 1317,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0'},
#  {'championId': 18,
#   'championLevel': 2,
#   'championPoints': 4634,
#   'lastPlayTime': 1526770659000,
#   'championPointsSinceLastLevel': 2834,
#   'championPointsUntilNextLevel': 1366,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0'},
#  {'championId': 20,
#   'championLevel': 2,
#   'championPoints': 4224,
#   'lastPlayTime': 1661143186000,
#   'championPointsSinceLastLevel': 2424,
#   'championPointsUntilNextLevel': 1776,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0'},
#  {'championId': 44,
#   'championLevel': 2,
#   'championPoints': 4037,
#   'lastPlayTime': 1674378204000,
#   'championPointsSinceLastLevel': 2237,
#   'championPointsUntilNextLevel': 1963,
#   'chestGranted': True,
#   'tokensEarned': 0,
#   'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0'},
#  {'championId': 267,
#   'championLevel': 2,
#   'championPoints': 4010,
#   'lastPlayTime': 1624516892000,
#   'championPointsSinceLastLevel': 2210,
#   'championPointsUntilNextLevel': 1990,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0'},
#  {'championId': 83,
#   'championLevel': 2,
#   'championPoints': 3785,
#   'lastPlayTime': 1521776823000,
#   'championPointsSinceLastLevel': 1985,
#   'championPointsUntilNextLevel': 2215,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0'},
#  {'championId': 157,
#   'championLevel': 2,
#   'championPoints': 3731,
#   'lastPlayTime': 1537586539000,
#   'championPointsSinceLastLevel': 1931,
#   'championPointsUntilNextLevel': 2269,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0'},
#  {'championId': 90,
#   'championLevel': 2,
#   'championPoints': 3722,
#   'lastPlayTime': 1526934952000,
#   'championPointsSinceLastLevel': 1922,
#   'championPointsUntilNextLevel': 2278,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0'},
#  {'championId': 80,
#   'championLevel': 2,
#   'championPoints': 3702,
#   'lastPlayTime': 1596780583000,
#   'championPointsSinceLastLevel': 1902,
#   'championPointsUntilNextLevel': 2298,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0'},
#  {'championId': 103,
#   'championLevel': 2,
#   'championPoints': 3607,
#   'lastPlayTime': 1575179508000,
#   'championPointsSinceLastLevel': 1807,
#   'championPointsUntilNextLevel': 2393,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0'},
#  {'championId': 7,
#   'championLevel': 2,
#   'championPoints': 3435,
#   'lastPlayTime': 1527139842000,
#   'championPointsSinceLastLevel': 1635,
#   'championPointsUntilNextLevel': 2565,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0'},
#  {'championId': 82,
#   'championLevel': 2,
#   'championPoints': 3102,
#   'lastPlayTime': 1669178660000,
#   'championPointsSinceLastLevel': 1302,
#   'championPointsUntilNextLevel': 2898,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0'},
#  {'championId': 54,
#   'championLevel': 2,
#   'championPoints': 3046,
#   'lastPlayTime': 1526936016000,
#   'championPointsSinceLastLevel': 1246,
#   'championPointsUntilNextLevel': 2954,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0'},
#  {'championId': 222,
#   'championLevel': 2,
#   'championPoints': 3019,
#   'lastPlayTime': 1537679229000,
#   'championPointsSinceLastLevel': 1219,
#   'championPointsUntilNextLevel': 2981,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0'},
#  {'championId': 143,
#   'championLevel': 2,
#   'championPoints': 2718,
#   'lastPlayTime': 1571710817000,
#   'championPointsSinceLastLevel': 918,
#   'championPointsUntilNextLevel': 3282,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0'},
#  {'championId': 203,
#   'championLevel': 2,
#   'championPoints': 2661,
#   'lastPlayTime': 1597031447000,
#   'championPointsSinceLastLevel': 861,
#   'championPointsUntilNextLevel': 3339,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0'},
#  {'championId': 61,
#   'championLevel': 2,
#   'championPoints': 2619,
#   'lastPlayTime': 1674026258000,
#   'championPointsSinceLastLevel': 819,
#   'championPointsUntilNextLevel': 3381,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0'},
#  {'championId': 30,
#   'championLevel': 2,
#   'championPoints': 2607,
#   'lastPlayTime': 1669349522000,
#   'championPointsSinceLastLevel': 807,
#   'championPointsUntilNextLevel': 3393,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0'},
#  {'championId': 104,
#   'championLevel': 2,
#   'championPoints': 2431,
#   'lastPlayTime': 1516818682000,
#   'championPointsSinceLastLevel': 631,
#   'championPointsUntilNextLevel': 3569,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0'},
#  {'championId': 55,
#   'championLevel': 2,
#   'championPoints': 2426,
#   'lastPlayTime': 1653887332000,
#   'championPointsSinceLastLevel': 626,
#   'championPointsUntilNextLevel': 3574,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0'},
#  {'championId': 67,
#   'championLevel': 2,
#   'championPoints': 2425,
#   'lastPlayTime': 1624001021000,
#   'championPointsSinceLastLevel': 625,
#   'championPointsUntilNextLevel': 3575,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0'},
#  {'championId': 23,
#   'championLevel': 2,
#   'championPoints': 2415,
#   'lastPlayTime': 1527627080000,
#   'championPointsSinceLastLevel': 615,
#   'championPointsUntilNextLevel': 3585,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0'},
#  {'championId': 9,
#   'championLevel': 2,
#   'championPoints': 2293,
#   'lastPlayTime': 1637547887000,
#   'championPointsSinceLastLevel': 493,
#   'championPointsUntilNextLevel': 3707,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0'},
#  {'championId': 427,
#   'championLevel': 2,
#   'championPoints': 2287,
#   'lastPlayTime': 1611477822000,
#   'championPointsSinceLastLevel': 487,
#   'championPointsUntilNextLevel': 3713,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0'},
#  {'championId': 99,
#   'championLevel': 2,
#   'championPoints': 2202,
#   'lastPlayTime': 1673501400000,
#   'championPointsSinceLastLevel': 402,
#   'championPointsUntilNextLevel': 3798,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0'},
#  {'championId': 26,
#   'championLevel': 2,
#   'championPoints': 2199,
#   'lastPlayTime': 1537588376000,
#   'championPointsSinceLastLevel': 399,
#   'championPointsUntilNextLevel': 3801,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0'},
#  {'championId': 62,
#   'championLevel': 2,
#   'championPoints': 2126,
#   'lastPlayTime': 1588398744000,
#   'championPointsSinceLastLevel': 326,
#   'championPointsUntilNextLevel': 3874,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0'},
#  {'championId': 69,
#   'championLevel': 2,
#   'championPoints': 2085,
#   'lastPlayTime': 1634360709000,
#   'championPointsSinceLastLevel': 285,
#   'championPointsUntilNextLevel': 3915,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0'},
#  {'championId': 161,
#   'championLevel': 2,
#   'championPoints': 1947,
#   'lastPlayTime': 1528141191000,
#   'championPointsSinceLastLevel': 147,
#   'championPointsUntilNextLevel': 4053,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0'},
#  {'championId': 57,
#   'championLevel': 2,
#   'championPoints': 1870,
#   'lastPlayTime': 1674455102000,
#   'championPointsSinceLastLevel': 70,
#   'championPointsUntilNextLevel': 4130,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0'},
#  {'championId': 106,
#   'championLevel': 1,
#   'championPoints': 1729,
#   'lastPlayTime': 1673775280000,
#   'championPointsSinceLastLevel': 1729,
#   'championPointsUntilNextLevel': 71,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0'},
#  {'championId': 3,
#   'championLevel': 1,
#   'championPoints': 1580,
#   'lastPlayTime': 1674453479000,
#   'championPointsSinceLastLevel': 1580,
#   'championPointsUntilNextLevel': 220,
#   'chestGranted': True,
#   'tokensEarned': 0,
#   'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0'},
#  {'championId': 35,
#   'championLevel': 1,
#   'championPoints': 1516,
#   'lastPlayTime': 1518366749000,
#   'championPointsSinceLastLevel': 1516,
#   'championPointsUntilNextLevel': 284,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0'},
#  {'championId': 127,
#   'championLevel': 1,
#   'championPoints': 1469,
#   'lastPlayTime': 1575519516000,
#   'championPointsSinceLastLevel': 1469,
#   'championPointsUntilNextLevel': 331,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0'},
#  {'championId': 142,
#   'championLevel': 1,
#   'championPoints': 1432,
#   'lastPlayTime': 1528695594000,
#   'championPointsSinceLastLevel': 1432,
#   'championPointsUntilNextLevel': 368,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0'},
#  {'championId': 110,
#   'championLevel': 1,
#   'championPoints': 1110,
#   'lastPlayTime': 1579063537000,
#   'championPointsSinceLastLevel': 1110,
#   'championPointsUntilNextLevel': 690,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0'},
#  {'championId': 41,
#   'championLevel': 1,
#   'championPoints': 1097,
#   'lastPlayTime': 1653446230000,
#   'championPointsSinceLastLevel': 1097,
#   'championPointsUntilNextLevel': 703,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0'},
#  {'championId': 64,
#   'championLevel': 1,
#   'championPoints': 1026,
#   'lastPlayTime': 1512195036000,
#   'championPointsSinceLastLevel': 1026,
#   'championPointsUntilNextLevel': 774,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0'},
#  {'championId': 147,
#   'championLevel': 1,
#   'championPoints': 1024,
#   'lastPlayTime': 1623215396000,
#   'championPointsSinceLastLevel': 1024,
#   'championPointsUntilNextLevel': 776,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0'},
#  {'championId': 34,
#   'championLevel': 1,
#   'championPoints': 1000,
#   'lastPlayTime': 1527141493000,
#   'championPointsSinceLastLevel': 1000,
#   'championPointsUntilNextLevel': 800,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0'},
#  {'championId': 28,
#   'championLevel': 1,
#   'championPoints': 979,
#   'lastPlayTime': 1527134087000,
#   'championPointsSinceLastLevel': 979,
#   'championPointsUntilNextLevel': 821,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0'},
#  {'championId': 101,
#   'championLevel': 1,
#   'championPoints': 914,
#   'lastPlayTime': 1599455311000,
#   'championPointsSinceLastLevel': 914,
#   'championPointsUntilNextLevel': 886,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0'},
#  {'championId': 429,
#   'championLevel': 1,
#   'championPoints': 862,
#   'lastPlayTime': 1525568344000,
#   'championPointsSinceLastLevel': 862,
#   'championPointsUntilNextLevel': 938,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0'},
#  {'championId': 421,
#   'championLevel': 1,
#   'championPoints': 842,
#   'lastPlayTime': 1519967896000,
#   'championPointsSinceLastLevel': 842,
#   'championPointsUntilNextLevel': 958,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0'},
#  {'championId': 136,
#   'championLevel': 1,
#   'championPoints': 799,
#   'lastPlayTime': 1522657649000,
#   'championPointsSinceLastLevel': 799,
#   'championPointsUntilNextLevel': 1001,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0'},
#  {'championId': 91,
#   'championLevel': 1,
#   'championPoints': 792,
#   'lastPlayTime': 1567831349000,
#   'championPointsSinceLastLevel': 792,
#   'championPointsUntilNextLevel': 1008,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0'},
#  {'championId': 77,
#   'championLevel': 1,
#   'championPoints': 767,
#   'lastPlayTime': 1521084785000,
#   'championPointsSinceLastLevel': 767,
#   'championPointsUntilNextLevel': 1033,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0'},
#  {'championId': 4,
#   'championLevel': 1,
#   'championPoints': 763,
#   'lastPlayTime': 1674380230000,
#   'championPointsSinceLastLevel': 763,
#   'championPointsUntilNextLevel': 1037,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0'},
#  {'championId': 134,
#   'championLevel': 1,
#   'championPoints': 738,
#   'lastPlayTime': 1527709350000,
#   'championPointsSinceLastLevel': 738,
#   'championPointsUntilNextLevel': 1062,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0'},
#  {'championId': 96,
#   'championLevel': 1,
#   'championPoints': 724,
#   'lastPlayTime': 1512763882000,
#   'championPointsSinceLastLevel': 724,
#   'championPointsUntilNextLevel': 1076,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0'},
#  {'championId': 85,
#   'championLevel': 1,
#   'championPoints': 720,
#   'lastPlayTime': 1487656492000,
#   'championPointsSinceLastLevel': 720,
#   'championPointsUntilNextLevel': 1080,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0'},
#  {'championId': 238,
#   'championLevel': 1,
#   'championPoints': 647,
#   'lastPlayTime': 1518760888000,
#   'championPointsSinceLastLevel': 647,
#   'championPointsUntilNextLevel': 1153,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0'},
#  {'championId': 133,
#   'championLevel': 1,
#   'championPoints': 645,
#   'lastPlayTime': 1555876306000,
#   'championPointsSinceLastLevel': 645,
#   'championPointsUntilNextLevel': 1155,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0'},
#  {'championId': 60,
#   'championLevel': 1,
#   'championPoints': 621,
#   'lastPlayTime': 1539809762000,
#   'championPointsSinceLastLevel': 621,
#   'championPointsUntilNextLevel': 1179,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0'},
#  {'championId': 145,
#   'championLevel': 1,
#   'championPoints': 612,
#   'lastPlayTime': 1528861963000,
#   'championPointsSinceLastLevel': 612,
#   'championPointsUntilNextLevel': 1188,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0'},
#  {'championId': 432,
#   'championLevel': 1,
#   'championPoints': 577,
#   'lastPlayTime': 1520230681000,
#   'championPointsSinceLastLevel': 577,
#   'championPointsUntilNextLevel': 1223,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0'},
#  {'championId': 79,
#   'championLevel': 1,
#   'championPoints': 508,
#   'lastPlayTime': 1624085498000,
#   'championPointsSinceLastLevel': 508,
#   'championPointsUntilNextLevel': 1292,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0'},
#  {'championId': 74,
#   'championLevel': 1,
#   'championPoints': 427,
#   'lastPlayTime': 1528701189000,
#   'championPointsSinceLastLevel': 427,
#   'championPointsUntilNextLevel': 1373,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0'},
#  {'championId': 121,
#   'championLevel': 1,
#   'championPoints': 299,
#   'lastPlayTime': 1544075232000,
#   'championPointsSinceLastLevel': 299,
#   'championPointsUntilNextLevel': 1501,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0'},
#  {'championId': 24,
#   'championLevel': 1,
#   'championPoints': 288,
#   'lastPlayTime': 1575769223000,
#   'championPointsSinceLastLevel': 288,
#   'championPointsUntilNextLevel': 1512,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0'},
#  {'championId': 51,
#   'championLevel': 1,
#   'championPoints': 271,
#   'lastPlayTime': 1539401827000,
#   'championPointsSinceLastLevel': 271,
#   'championPointsUntilNextLevel': 1529,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0'},
#  {'championId': 84,
#   'championLevel': 1,
#   'championPoints': 223,
#   'lastPlayTime': 1539498370000,
#   'championPointsSinceLastLevel': 223,
#   'championPointsUntilNextLevel': 1577,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0'},
#  {'championId': 42,
#   'championLevel': 1,
#   'championPoints': 191,
#   'lastPlayTime': 1539492132000,
#   'championPointsSinceLastLevel': 191,
#   'championPointsUntilNextLevel': 1609,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0'},
#  {'championId': 350,
#   'championLevel': 1,
#   'championPoints': 167,
#   'lastPlayTime': 1676169021000,
#   'championPointsSinceLastLevel': 167,
#   'championPointsUntilNextLevel': 1633,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0'},
#  {'championId': 105,
#   'championLevel': 1,
#   'championPoints': 164,
#   'lastPlayTime': 1607154494000,
#   'championPointsSinceLastLevel': 164,
#   'championPointsUntilNextLevel': 1636,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0'},
#  {'championId': 119,
#   'championLevel': 1,
#   'championPoints': 155,
#   'lastPlayTime': 1503286807000,
#   'championPointsSinceLastLevel': 155,
#   'championPointsUntilNextLevel': 1645,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0'},
#  {'championId': 141,
#   'championLevel': 1,
#   'championPoints': 149,
#   'lastPlayTime': 1576379945000,
#   'championPointsSinceLastLevel': 149,
#   'championPointsUntilNextLevel': 1651,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0'},
#  {'championId': 2,
#   'championLevel': 1,
#   'championPoints': 130,
#   'lastPlayTime': 1523167912000,
#   'championPointsSinceLastLevel': 130,
#   'championPointsUntilNextLevel': 1670,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0'},
#  {'championId': 58,
#   'championLevel': 1,
#   'championPoints': 126,
#   'lastPlayTime': 1539751829000,
#   'championPointsSinceLastLevel': 126,
#   'championPointsUntilNextLevel': 1674,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0'},
#  {'championId': 498,
#   'championLevel': 1,
#   'championPoints': 119,
#   'lastPlayTime': 1557860248000,
#   'championPointsSinceLastLevel': 119,
#   'championPointsUntilNextLevel': 1681,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0'},
#  {'championId': 268,
#   'championLevel': 1,
#   'championPoints': 112,
#   'lastPlayTime': 1519969202000,
#   'championPointsSinceLastLevel': 112,
#   'championPointsUntilNextLevel': 1688,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0'},
#  {'championId': 164,
#   'championLevel': 1,
#   'championPoints': 108,
#   'lastPlayTime': 1552789176000,
#   'championPointsSinceLastLevel': 108,
#   'championPointsUntilNextLevel': 1692,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0'},
#  {'championId': 107,
#   'championLevel': 1,
#   'championPoints': 108,
#   'lastPlayTime': 1524515657000,
#   'championPointsSinceLastLevel': 108,
#   'championPointsUntilNextLevel': 1692,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0'},
#  {'championId': 6,
#   'championLevel': 1,
#   'championPoints': 101,
#   'lastPlayTime': 1522651711000,
#   'championPointsSinceLastLevel': 101,
#   'championPointsUntilNextLevel': 1699,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0'},
#  {'championId': 72,
#   'championLevel': 1,
#   'championPoints': 92,
#   'lastPlayTime': 1513453088000,
#   'championPointsSinceLastLevel': 92,
#   'championPointsUntilNextLevel': 1708,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0'}]

# %%
r2 = requests.get(url + summ_request + encryptedAccountId + "?api_key=" + API_KEY)
r2.json()
# Out:
# {'id': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0',
#  'accountId': 'x1jjbMOl33kYCZs0y5HfCmvPwQD-Ai-QubugHIx5kEUtiFI',
#  'puuid': 'G-7wmI2szoObELtiJno5R3xgCbYsJSPnugX8twyJBNJEfYqeNn_JlKVLpePqQo2NSIdQ_g06GJuLeg',
#  'name': 'Wargoblin77',
#  'profileIconId': 13,
#  'revisionDate': 1676172169000,
#  'summonerLevel': 159}

# %%
r3 = requests.get(url + account_request + ign_tag + "?api_key=" + API_KEY)
r3.json()
# Out:
# {'status': {'message': 'Bad request - Invalid routing value na1',
#   'status_code': 400}}

# %%
r4 = requests.get(url + "/riot/account/v1/accounts/me")

# %%
r5 = requests.get("https://americas.api.riotgames.com/lol/match/v5/matches/by-puuid/G-7wmI2szoObELtiJno5R3xgCbYsJSPnugX8twyJBNJEfYqeNn_JlKVLpePqQo2NSIdQ_g06GJuLeg/ids?start=0&count=100&api_key=RGAPI-943f21fe-d765-4959-9db9-71565933aec3")
r5.json()
# Out:
# ['NA1_4575201902',
#  'NA1_4575167402',
#  'NA1_4556635359',
#  'NA1_4556616977',
#  'NA1_4555724078',
#  'NA1_4555707383',
#  'NA1_4555704846',
#  'NA1_4555690905',
#  'NA1_4555681866',
#  'NA1_4551620202',
#  'NA1_4551598192',
#  'NA1_4551573594',
#  'NA1_4551559069',
#  'NA1_4551535291',
#  'NA1_4548538472',
#  'NA1_4548532452',
#  'NA1_4548528922',
#  'NA1_4548505546',
#  'NA1_4548485622',
#  'NA1_4548468289',
#  'NA1_4548454737',
#  'NA1_4548424700',
#  'NA1_4545229325',
#  'NA1_4545212165',
#  'NA1_4545197904',
#  'NA1_4545170411',
#  'NA1_4501492072',
#  'NA1_4501457254',
#  'NA1_4501415344',
#  'NA1_4499955608',
#  'NA1_4499938572',
#  'NA1_4499919867',
#  'NA1_4499890055',
#  'NA1_4441437730',
#  'NA1_4441443721',
#  'NA1_4412758078',
#  'NA1_4412705183',
#  'NA1_4412698344',
#  'NA1_4412659982',
#  'NA1_4412612397',
#  'NA1_4407500591',
#  'NA1_4407432160',
#  'NA1_4407386837',
#  'NA1_4407390684',
#  'NA1_4405797837',
#  'NA1_4405778969',
#  'NA1_4398944845',
#  'NA1_4398876182',
#  'NA1_4370498533',
#  'NA1_4369511008',
#  'NA1_4324630408',
#  'NA1_4324616365',
#  'NA1_4324602716',
#  'NA1_4324518981',
#  'NA1_4324543558',
#  'NA1_4324550764',
#  'NA1_4324496074',
#  'NA1_4324462623',
#  'NA1_4324419406',
#  'NA1_4324436797',
#  'NA1_4324389462',
#  'NA1_4324373142',
#  'NA1_4319124522',
#  'NA1_4319120665',
#  'NA1_4319038591',
#  'NA1_4319034680',
#  'NA1_4319016241',
#  'NA1_4319001463',
#  'NA1_4318946090',
#  'NA1_4253093898',
#  'NA1_4253029141',
#  'NA1_4178510073',
#  'NA1_4166328743',
#  'NA1_4143817718',
#  'NA1_4143779712',
#  'NA1_4112486797',
#  'NA1_4112467913',
#  'NA1_4112357088',
#  'NA1_4112267415',
#  'NA1_4112293421',
#  'NA1_4092980670',
#  'NA1_4092873091',
#  'NA1_4092854834',
#  'NA1_4087849661',
#  'NA1_4087836581',
#  'NA1_4087844167',
#  'NA1_4074494912',
#  'NA1_4074437731',
#  'NA1_4074387339',
#  'NA1_4072599921',
#  'NA1_4072545613',
#  'NA1_4072543178',
#  'NA1_4072509603',
#  'NA1_4072516100',
#  'NA1_4067918947',
#  'NA1_4067935864',
#  'NA1_4067973135',
#  'NA1_4067930879',
#  'NA1_4067898163',
#  'NA1_4067855539']

# %%
r6 = requests.get("https://americas.api.riotgames.com/lol/match/v5/matches/NA1_4545212165?api_key=RGAPI-943f21fe-d765-4959-9db9-71565933aec3")
r6.json()
# Out:
# {'metadata': {'dataVersion': '2',
#   'matchId': 'NA1_4545212165',
#   'participants': ['RLFwP7RS3SI8tXxZrsrrEcda3miLaG2MWsFnYSKYrmMeiMVePqfWR1W-rBxozdDJTGlHa6tUEhNf9A',
#    '5Fm4XHgU7mpYkCqLhjxBNo6JGyoRKeCSUS-zfKIKXkQUkOUndFl0YD8WaL0KcFSvO-VufcimSwv28Q',
#    'G-7wmI2szoObELtiJno5R3xgCbYsJSPnugX8twyJBNJEfYqeNn_JlKVLpePqQo2NSIdQ_g06GJuLeg',
#    'fA7mCb6WNZMiqvzulHyfV30dyQZIKH9DDqyn4HRrRl7yI8c7Y2Qt68Wo7Ofy2Es45Tf8mLMag5jnhw',
#    'fq3n5PJ7YoapfPW7r4jMszpA0dJe78xaf9aOGgbQo5Z1MZiccFT_2xgGwFJR1G8ABPmRex2AkvvuBg',
#    'KYrJq363rjMUXOT26AaC0ATaZpRvUkXDQ2dXl_CT71HzetUZXMkD3Dq0VJXxdn434KEwhd6QzA49Ow',
#    '9-VzRrwCCwXuYNnHybVNlsZidhcnWX8TSOv8biYAIgpsT_1FVX5ljrdUt2Zma2inzjnL_ZJhXUD81g',
#    '9rbfodBBClKmvQUuHYNFrBzbaOVO-Dh1n_lnwDriWdE3bekR_y6UMnHOVpqb8T-WiLFZV-rxtnry1Q',
#    'aRrSlfzQHMgyHguY2QWUrWTLz8zUvPRVurC0xeAUQvmFB3B_Wd9WH1VKmQak30zrZsri-fGPMwSb3w',
#    'fp31Ko2pLW9APgmtCdg9X7rdKbPdcw3HcOEXdzlRm-ddyLj27mAE2hQfPyoQ7XQME9Ad9SqPpE2wlg']},
#  'info': {'gameCreation': 1673502615607,
#   'gameDuration': 989,
#   'gameEndTimestamp': 1673503635315,
#   'gameId': 4545212165,
#   'gameMode': 'ARAM',
#   'gameName': 'teambuilder-match-4545212165',
#   'gameStartTimestamp': 1673502645603,
#   'gameType': 'MATCHED_GAME',
#   'gameVersion': '13.1.487.9641',
#   'mapId': 12,
#   'participants': [{'allInPings': 0,
#     'assistMePings': 0,
#     'assists': 27,
#     'baitPings': 0,
#     'baronKills': 0,
#     'basicPings': 0,
#     'bountyLevel': 2,
#     'challenges': {'12AssistStreakCount': 0,
#      'abilityUses': 188,
#      'acesBefore15Minutes': 3,
#      'alliedJungleMonsterKills': 0,
#      'baronTakedowns': 0,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 0,
#      'buffsStolen': 0,
#      'completeSupportQuestInTime': 0,
#      'controlWardsPlaced': 0,
#      'damagePerMinute': 1840.8564774893928,
#      'damageTakenOnTeamPercentage': 0.1770273039246854,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 6,
#      'dodgeSkillShotsSmallWindow': 3,
#      'doubleAces': 0,
#      'dragonTakedowns': 0,
#      'earlyLaningPhaseGoldExpAdvantage': 0,
#      'effectiveHealAndShielding': 0,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 31,
#      'enemyJungleMonsterKills': 0,
#      'epicMonsterKillsNearEnemyJungler': 0,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'flawlessAces': 1,
#      'fullTeamTakedown': 18,
#      'gameLength': 989.7760772800383,
#      'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#      'goldPerMinute': 781.0497674629858,
#      'hadOpenNexus': 0,
#      'immobilizeAndKillWithAlly': 18,
#      'initialBuffCount': 0,
#      'initialCrabCount': 0,
#      'jungleCsBefore10Minutes': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 0,
#      'kTurretsDestroyedBeforePlatesFall': 0,
#      'kda': 5.125,
#      'killAfterHiddenWithAlly': 2,
#      'killParticipation': 0.6949152542372882,
#      'killedChampTookFullTeamDamageSurvived': 0,
#      'killingSprees': 2,
#      'killsNearEnemyTurret': 4,
#      'killsOnOtherLanesEarlyJungleAsLaner': 0,
#      'killsOnRecentlyHealedByAramPack': 0,
#      'killsUnderOwnTurret': 0,
#      'killsWithHelpFromEpicMonster': 0,
#      'knockEnemyIntoTeamAndKill': 0,
#      'landSkillShotsEarlyGame': 0,
#      'laneMinionsFirst10Minutes': 29,
#      'laningPhaseGoldExpAdvantage': 0,
#      'legendaryCount': 0,
#      'lostAnInhibitor': 0,
#      'maxCsAdvantageOnLaneOpponent': 3,
#      'maxKillDeficit': 1,
#      'maxLevelLeadLaneOpponent': 2,
#      'moreEnemyJungleThanOpponent': 0,
#      'multiKillOneSpell': 1,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 4,
#      'multikillsAfterAggressiveFlash': 0,
#      'mythicItemUsed': 6653,
#      'outerTurretExecutesBefore10Minutes': 1,
#      'outnumberedKills': 2,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 27,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 0,
#      'saveAllyFromDeath': 0,
#      'scuttleCrabKills': 0,
#      'shortestTimeToAceFromFirstTakedown': 7.038250364849546,
#      'skillshotsDodged': 20,
#      'skillshotsHit': 0,
#      'snowballsHit': 0,
#      'soloBaronKills': 0,
#      'soloKills': 0,
#      'stealthWardsPlaced': 0,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 0,
#      'takedownOnFirstTurret': 0,
#      'takedowns': 41,
#      'takedownsAfterGainingLevelAdvantage': 0,
#      'takedownsBeforeJungleMinionSpawn': 2,
#      'takedownsFirstXMinutes': 36,
#      'takedownsInAlcove': 0,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 0,
#      'teamDamagePercentage': 0.23872372112807708,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 0,
#      'threeWardsOneSweeperCount': 0,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 0,
#      'turretTakedowns': 3,
#      'turretsTakenWithRiftHerald': 0,
#      'twentyMinionsIn3SecondsCount': 2,
#      'unseenRecalls': 0,
#      'visionScoreAdvantageLaneOpponent': -1,
#      'visionScorePerMinute': 0,
#      'wardTakedowns': 0,
#      'wardTakedownsBefore20M': 0,
#      'wardsGuarded': 0},
#     'champExperience': 17611,
#     'champLevel': 17,
#     'championId': 136,
#     'championName': 'AurelionSol',
#     'championTransform': 0,
#     'commandPings': 1,
#     'consumablesPurchased': 0,
#     'damageDealtToBuildings': 1925,
#     'damageDealtToObjectives': 1925,
#     'damageDealtToTurrets': 1925,
#     'damageSelfMitigated': 8023,
#     'dangerPings': 0,
#     'deaths': 8,
#     'detectorWardsPlaced': 0,
#     'doubleKills': 4,
#     'dragonKills': 0,
#     'eligibleForProgression': True,
#     'enemyMissingPings': 0,
#     'enemyVisionPings': 0,
#     'firstBloodAssist': True,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'getBackPings': 0,
#     'goldEarned': 12884,
#     'goldSpent': 12200,
#     'holdPings': 0,
#     'individualPosition': 'Invalid',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 1,
#     'inhibitorsLost': 0,
#     'item0': 6653,
#     'item1': 3020,
#     'item2': 3116,
#     'item3': 4637,
#     'item4': 3145,
#     'item5': 1058,
#     'item6': 2052,
#     'itemsPurchased': 14,
#     'killingSprees': 5,
#     'kills': 14,
#     'lane': 'NONE',
#     'largestCriticalStrike': 0,
#     'largestKillingSpree': 5,
#     'largestMultiKill': 2,
#     'longestTimeSpentLiving': 160,
#     'magicDamageDealt': 62782,
#     'magicDamageDealtToChampions': 29905,
#     'magicDamageTaken': 4152,
#     'needVisionPings': 0,
#     'neutralMinionsKilled': 0,
#     'nexusKills': 0,
#     'nexusLost': 0,
#     'nexusTakedowns': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'onMyWayPings': 0,
#     'participantId': 1,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5001, 'flex': 5008, 'offense': 5007},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8230, 'var1': 17, 'var2': 0, 'var3': 0},
#         {'perk': 8275, 'var1': 8, 'var2': 0, 'var3': 0},
#         {'perk': 8234, 'var1': 6951, 'var2': 0, 'var3': 0},
#         {'perk': 8236, 'var1': 24, 'var2': 0, 'var3': 0}],
#        'style': 8200},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8009, 'var1': 5434, 'var2': 0, 'var3': 0},
#         {'perk': 8299, 'var1': 1643, 'var2': 0, 'var3': 0}],
#        'style': 8000}]},
#     'physicalDamageDealt': 880,
#     'physicalDamageDealtToChampions': 461,
#     'physicalDamageTaken': 11847,
#     'profileIcon': 5659,
#     'pushPings': 0,
#     'puuid': 'RLFwP7RS3SI8tXxZrsrrEcda3miLaG2MWsFnYSKYrmMeiMVePqfWR1W-rBxozdDJTGlHa6tUEhNf9A',
#     'quadraKills': 0,
#     'riotIdName': '',
#     'riotIdTagline': '',
#     'role': 'SUPPORT',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 64,
#     'spell2Casts': 110,
#     'spell3Casts': 7,
#     'spell4Casts': 7,
#     'summoner1Casts': 5,
#     'summoner1Id': 6,
#     'summoner2Casts': 3,
#     'summoner2Id': 4,
#     'summonerId': 'UkC3622wzFeYuZ82Ozdz2JHM2_ISWyUqrQNnbideGfi1D2A',
#     'summonerLevel': 534,
#     'summonerName': 'CHEEZENINJA',
#     'teamEarlySurrendered': False,
#     'teamId': 100,
#     'teamPosition': '',
#     'timeCCingOthers': 33,
#     'timePlayed': 989,
#     'totalDamageDealt': 63662,
#     'totalDamageDealtToChampions': 30367,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 19049,
#     'totalHeal': 1502,
#     'totalHealsOnTeammates': 0,
#     'totalMinionsKilled': 55,
#     'totalTimeCCDealt': 142,
#     'totalTimeSpentDead': 184,
#     'totalUnitsHealed': 1,
#     'tripleKills': 0,
#     'trueDamageDealt': 0,
#     'trueDamageDealtToChampions': 0,
#     'trueDamageTaken': 3048,
#     'turretKills': 2,
#     'turretTakedowns': 3,
#     'turretsLost': 1,
#     'unrealKills': 0,
#     'visionClearedPings': 0,
#     'visionScore': 0,
#     'visionWardsBoughtInGame': 0,
#     'wardsKilled': 0,
#     'wardsPlaced': 0,
#     'win': True},
#    {'allInPings': 0,
#     'assistMePings': 0,
#     'assists': 39,
#     'baitPings': 0,
#     'baronKills': 0,
#     'basicPings': 0,
#     'bountyLevel': 0,
#     'challenges': {'12AssistStreakCount': 1,
#      'abilityUses': 119,
#      'acesBefore15Minutes': 3,
#      'alliedJungleMonsterKills': 0,
#      'baronTakedowns': 0,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 150,
#      'buffsStolen': 0,
#      'completeSupportQuestInTime': 0,
#      'controlWardsPlaced': 0,
#      'damagePerMinute': 659.2732296449799,
#      'damageTakenOnTeamPercentage': 0.23643222555855925,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 10,
#      'dodgeSkillShotsSmallWindow': 4,
#      'doubleAces': 0,
#      'dragonTakedowns': 0,
#      'earlyLaningPhaseGoldExpAdvantage': 0,
#      'effectiveHealAndShielding': 353.10504150390625,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 63,
#      'enemyJungleMonsterKills': 0,
#      'epicMonsterKillsNearEnemyJungler': 0,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'flawlessAces': 1,
#      'fullTeamTakedown': 18,
#      'gameLength': 989.7760772800383,
#      'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#      'goldPerMinute': 672.9864402630819,
#      'hadOpenNexus': 0,
#      'immobilizeAndKillWithAlly': 23,
#      'initialBuffCount': 0,
#      'initialCrabCount': 0,
#      'jungleCsBefore10Minutes': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 0,
#      'kTurretsDestroyedBeforePlatesFall': 1,
#      'kda': 4.3,
#      'killAfterHiddenWithAlly': 3,
#      'killParticipation': 0.7288135593220338,
#      'killedChampTookFullTeamDamageSurvived': 0,
#      'killsNearEnemyTurret': 1,
#      'killsOnOtherLanesEarlyJungleAsLaner': 0,
#      'killsOnRecentlyHealedByAramPack': 0,
#      'killsUnderOwnTurret': 0,
#      'killsWithHelpFromEpicMonster': 0,
#      'knockEnemyIntoTeamAndKill': 14,
#      'landSkillShotsEarlyGame': 7,
#      'laneMinionsFirst10Minutes': 5,
#      'laningPhaseGoldExpAdvantage': 0,
#      'legendaryCount': 0,
#      'lostAnInhibitor': 0,
#      'maxCsAdvantageOnLaneOpponent': 0,
#      'maxKillDeficit': 1,
#      'maxLevelLeadLaneOpponent': 2,
#      'moreEnemyJungleThanOpponent': 0,
#      'multiKillOneSpell': 0,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 0,
#      'multikillsAfterAggressiveFlash': 0,
#      'mythicItemUsed': 6665,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 1,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 26,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 0,
#      'saveAllyFromDeath': 1,
#      'scuttleCrabKills': 0,
#      'shortestTimeToAceFromFirstTakedown': 7.038250364849546,
#      'skillshotsDodged': 28,
#      'skillshotsHit': 17,
#      'snowballsHit': 6,
#      'soloBaronKills': 0,
#      'soloKills': 1,
#      'stealthWardsPlaced': 0,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 1,
#      'takedownOnFirstTurret': 1,
#      'takedowns': 43,
#      'takedownsAfterGainingLevelAdvantage': 0,
#      'takedownsBeforeJungleMinionSpawn': 3,
#      'takedownsFirstXMinutes': 38,
#      'takedownsInAlcove': 0,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 0,
#      'teamDamagePercentage': 0.08549507283458592,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 0,
#      'threeWardsOneSweeperCount': 0,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 0,
#      'turretTakedowns': 2,
#      'turretsTakenWithRiftHerald': 0,
#      'twentyMinionsIn3SecondsCount': 0,
#      'unseenRecalls': 0,
#      'visionScoreAdvantageLaneOpponent': -1,
#      'visionScorePerMinute': 0,
#      'wardTakedowns': 0,
#      'wardTakedownsBefore20M': 0,
#      'wardsGuarded': 0},
#     'champExperience': 16494,
#     'champLevel': 17,
#     'championId': 526,
#     'championName': 'Rell',
#     'championTransform': 0,
#     'commandPings': 0,
#     'consumablesPurchased': 0,
#     'damageDealtToBuildings': 241,
#     'damageDealtToObjectives': 241,
#     'damageDealtToTurrets': 241,
#     'damageSelfMitigated': 43063,
#     'dangerPings': 0,
#     'deaths': 10,
#     'detectorWardsPlaced': 0,
#     'doubleKills': 0,
#     'dragonKills': 0,
#     'eligibleForProgression': True,
#     'enemyMissingPings': 0,
#     'enemyVisionPings': 0,
#     'firstBloodAssist': True,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'getBackPings': 0,
#     'goldEarned': 11101,
#     'goldSpent': 9500,
#     'holdPings': 0,
#     'individualPosition': 'Invalid',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 1,
#     'inhibitorsLost': 0,
#     'item0': 3111,
#     'item1': 6665,
#     'item2': 3076,
#     'item3': 3068,
#     'item4': 1057,
#     'item5': 3066,
#     'item6': 2052,
#     'itemsPurchased': 17,
#     'killingSprees': 0,
#     'kills': 4,
#     'lane': 'NONE',
#     'largestCriticalStrike': 2,
#     'largestKillingSpree': 0,
#     'largestMultiKill': 1,
#     'longestTimeSpentLiving': 133,
#     'magicDamageDealt': 13816,
#     'magicDamageDealtToChampions': 8272,
#     'magicDamageTaken': 4865,
#     'needVisionPings': 0,
#     'neutralMinionsKilled': 0,
#     'nexusKills': 0,
#     'nexusLost': 0,
#     'nexusTakedowns': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'onMyWayPings': 0,
#     'participantId': 2,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5003, 'flex': 5002, 'offense': 5007},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8439, 'var1': 691, 'var2': 1181, 'var3': 0},
#         {'perk': 8463, 'var1': 491, 'var2': 0, 'var3': 0},
#         {'perk': 8429, 'var1': 51, 'var2': 16, 'var3': 15},
#         {'perk': 8451, 'var1': 239, 'var2': 0, 'var3': 0}],
#        'style': 8400},
#       {'description': 'subStyle',
#        'selections': [{'perk': 9111, 'var1': 2066, 'var2': 430, 'var3': 0},
#         {'perk': 9105, 'var1': 4, 'var2': 0, 'var3': 0}],
#        'style': 8000}]},
#     'physicalDamageDealt': 2658,
#     'physicalDamageDealtToChampions': 1912,
#     'physicalDamageTaken': 16408,
#     'profileIcon': 5408,
#     'pushPings': 0,
#     'puuid': '5Fm4XHgU7mpYkCqLhjxBNo6JGyoRKeCSUS-zfKIKXkQUkOUndFl0YD8WaL0KcFSvO-VufcimSwv28Q',
#     'quadraKills': 0,
#     'riotIdName': '',
#     'riotIdTagline': '',
#     'role': 'SUPPORT',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 52,
#     'spell2Casts': 31,
#     'spell3Casts': 31,
#     'spell4Casts': 5,
#     'summoner1Casts': 15,
#     'summoner1Id': 32,
#     'summoner2Casts': 3,
#     'summoner2Id': 4,
#     'summonerId': 'qEm1-Sp1lY1gkoJo4hY38bDcW0xWSRPQBqQrxLO66fpD7sw',
#     'summonerLevel': 187,
#     'summonerName': 'Kimchiihoon',
#     'teamEarlySurrendered': False,
#     'teamId': 100,
#     'teamPosition': '',
#     'timeCCingOthers': 29,
#     'timePlayed': 989,
#     'totalDamageDealt': 17165,
#     'totalDamageDealtToChampions': 10875,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 25441,
#     'totalHeal': 4067,
#     'totalHealsOnTeammates': 353,
#     'totalMinionsKilled': 7,
#     'totalTimeCCDealt': 55,
#     'totalTimeSpentDead': 228,
#     'totalUnitsHealed': 4,
#     'tripleKills': 0,
#     'trueDamageDealt': 690,
#     'trueDamageDealtToChampions': 690,
#     'trueDamageTaken': 4166,
#     'turretKills': 0,
#     'turretTakedowns': 2,
#     'turretsLost': 1,
#     'unrealKills': 0,
#     'visionClearedPings': 0,
#     'visionScore': 0,
#     'visionWardsBoughtInGame': 0,
#     'wardsKilled': 0,
#     'wardsPlaced': 0,
#     'win': True},
#    {'allInPings': 0,
#     'assistMePings': 0,
#     'assists': 33,
#     'baitPings': 0,
#     'baronKills': 0,
#     'basicPings': 0,
#     'bountyLevel': 0,
#     'challenges': {'12AssistStreakCount': 0,
#      'abilityUses': 109,
#      'acesBefore15Minutes': 3,
#      'alliedJungleMonsterKills': 0,
#      'baronTakedowns': 0,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 150,
#      'buffsStolen': 0,
#      'completeSupportQuestInTime': 0,
#      'controlWardsPlaced': 0,
#      'damagePerMinute': 745.6116501085631,
#      'damageTakenOnTeamPercentage': 0.22645629731763453,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 7,
#      'dodgeSkillShotsSmallWindow': 5,
#      'doubleAces': 0,
#      'dragonTakedowns': 0,
#      'earlyLaningPhaseGoldExpAdvantage': 0,
#      'effectiveHealAndShielding': 417.580810546875,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 34,
#      'enemyJungleMonsterKills': 0,
#      'epicMonsterKillsNearEnemyJungler': 0,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'flawlessAces': 1,
#      'fullTeamTakedown': 18,
#      'gameLength': 989.7760772800383,
#      'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#      'goldPerMinute': 672.3405200181646,
#      'hadOpenNexus': 0,
#      'immobilizeAndKillWithAlly': 19,
#      'initialBuffCount': 0,
#      'initialCrabCount': 0,
#      'jungleCsBefore10Minutes': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 0,
#      'kTurretsDestroyedBeforePlatesFall': 1,
#      'kda': 5.571428571428571,
#      'killAfterHiddenWithAlly': 6,
#      'killParticipation': 0.6610169491525424,
#      'killedChampTookFullTeamDamageSurvived': 0,
#      'killsNearEnemyTurret': 5,
#      'killsOnOtherLanesEarlyJungleAsLaner': 0,
#      'killsOnRecentlyHealedByAramPack': 0,
#      'killsUnderOwnTurret': 1,
#      'killsWithHelpFromEpicMonster': 0,
#      'knockEnemyIntoTeamAndKill': 0,
#      'landSkillShotsEarlyGame': 19,
#      'laneMinionsFirst10Minutes': 8,
#      'laningPhaseGoldExpAdvantage': 0,
#      'legendaryCount': 0,
#      'lostAnInhibitor': 0,
#      'maxCsAdvantageOnLaneOpponent': 0,
#      'maxKillDeficit': 1,
#      'maxLevelLeadLaneOpponent': 2,
#      'moreEnemyJungleThanOpponent': 0,
#      'multiKillOneSpell': 0,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 0,
#      'multikillsAfterAggressiveFlash': 0,
#      'mythicItemUsed': 6665,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 2,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 25,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 0,
#      'saveAllyFromDeath': 1,
#      'scuttleCrabKills': 0,
#      'shortestTimeToAceFromFirstTakedown': 7.038250364849546,
#      'skillshotsDodged': 32,
#      'skillshotsHit': 29,
#      'snowballsHit': 9,
#      'soloBaronKills': 0,
#      'soloKills': 0,
#      'stealthWardsPlaced': 0,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 5,
#      'takedownOnFirstTurret': 1,
#      'takedowns': 39,
#      'takedownsAfterGainingLevelAdvantage': 0,
#      'takedownsBeforeJungleMinionSpawn': 3,
#      'takedownsFirstXMinutes': 34,
#      'takedownsInAlcove': 0,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 0,
#      'teamDamagePercentage': 0.09669150735374896,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 0,
#      'threeWardsOneSweeperCount': 0,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 0,
#      'turretTakedowns': 4,
#      'turretsTakenWithRiftHerald': 0,
#      'twentyMinionsIn3SecondsCount': 0,
#      'unseenRecalls': 0,
#      'visionScoreAdvantageLaneOpponent': -1,
#      'visionScorePerMinute': 0,
#      'wardTakedowns': 0,
#      'wardTakedownsBefore20M': 0,
#      'wardsGuarded': 0},
#     'champExperience': 16459,
#     'champLevel': 16,
#     'championId': 3,
#     'championName': 'Galio',
#     'championTransform': 0,
#     'commandPings': 0,
#     'consumablesPurchased': 3,
#     'damageDealtToBuildings': 2283,
#     'damageDealtToObjectives': 2283,
#     'damageDealtToTurrets': 2283,
#     'damageSelfMitigated': 35285,
#     'dangerPings': 0,
#     'deaths': 7,
#     'detectorWardsPlaced': 0,
#     'doubleKills': 0,
#     'dragonKills': 0,
#     'eligibleForProgression': True,
#     'enemyMissingPings': 0,
#     'enemyVisionPings': 0,
#     'firstBloodAssist': True,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'getBackPings': 0,
#     'goldEarned': 11091,
#     'goldSpent': 9200,
#     'holdPings': 0,
#     'individualPosition': 'Invalid',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 1,
#     'inhibitorsLost': 0,
#     'item0': 2051,
#     'item1': 3070,
#     'item2': 6665,
#     'item3': 3111,
#     'item4': 3068,
#     'item5': 3076,
#     'item6': 2052,
#     'itemsPurchased': 18,
#     'killingSprees': 1,
#     'kills': 6,
#     'lane': 'NONE',
#     'largestCriticalStrike': 2,
#     'largestKillingSpree': 2,
#     'largestMultiKill': 1,
#     'longestTimeSpentLiving': 142,
#     'magicDamageDealt': 28548,
#     'magicDamageDealtToChampions': 10466,
#     'magicDamageTaken': 2364,
#     'needVisionPings': 0,
#     'neutralMinionsKilled': 0,
#     'nexusKills': 0,
#     'nexusLost': 0,
#     'nexusTakedowns': 1,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'onMyWayPings': 0,
#     'participantId': 3,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5002, 'flex': 5002, 'offense': 5008},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8439, 'var1': 420, 'var2': 1491, 'var3': 0},
#         {'perk': 8463, 'var1': 589, 'var2': 0, 'var3': 0},
#         {'perk': 8444, 'var1': 1346, 'var2': 0, 'var3': 0},
#         {'perk': 8453, 'var1': 181, 'var2': 660, 'var3': 0}],
#        'style': 8400},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8126, 'var1': 692, 'var2': 0, 'var3': 0},
#         {'perk': 8138, 'var1': 30, 'var2': 0, 'var3': 0}],
#        'style': 8100}]},
#     'physicalDamageDealt': 432,
#     'physicalDamageDealtToChampions': 402,
#     'physicalDamageTaken': 17705,
#     'profileIcon': 13,
#     'pushPings': 0,
#     'puuid': 'G-7wmI2szoObELtiJno5R3xgCbYsJSPnugX8twyJBNJEfYqeNn_JlKVLpePqQo2NSIdQ_g06GJuLeg',
#     'quadraKills': 0,
#     'riotIdName': '',
#     'riotIdTagline': '',
#     'role': 'SUPPORT',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 59,
#     'spell2Casts': 21,
#     'spell3Casts': 27,
#     'spell4Casts': 2,
#     'summoner1Casts': 21,
#     'summoner1Id': 32,
#     'summoner2Casts': 2,
#     'summoner2Id': 4,
#     'summonerId': 'HOVXGTcmpFqZFKQGNCArs5bmgd5kGnBEz3brE4rQmmjcca0',
#     'summonerLevel': 157,
#     'summonerName': 'Wargoblin77',
#     'teamEarlySurrendered': False,
#     'teamId': 100,
#     'teamPosition': '',
#     'timeCCingOthers': 20,
#     'timePlayed': 989,
#     'totalDamageDealt': 30661,
#     'totalDamageDealtToChampions': 12299,
#     'totalDamageShieldedOnTeammates': 166,
#     'totalDamageTaken': 24367,
#     'totalHeal': 2493,
#     'totalHealsOnTeammates': 250,
#     'totalMinionsKilled': 15,
#     'totalTimeCCDealt': 39,
#     'totalTimeSpentDead': 173,
#     'totalUnitsHealed': 4,
#     'tripleKills': 0,
#     'trueDamageDealt': 1681,
#     'trueDamageDealtToChampions': 1431,
#     'trueDamageTaken': 4297,
#     'turretKills': 1,
#     'turretTakedowns': 4,
#     'turretsLost': 1,
#     'unrealKills': 0,
#     'visionClearedPings': 0,
#     'visionScore': 0,
#     'visionWardsBoughtInGame': 0,
#     'wardsKilled': 0,
#     'wardsPlaced': 0,
#     'win': True},
#    {'allInPings': 0,
#     'assistMePings': 0,
#     'assists': 34,
#     'baitPings': 0,
#     'baronKills': 0,
#     'basicPings': 0,
#     'bountyLevel': 0,
#     'challenges': {'12AssistStreakCount': 0,
#      'abilityUses': 300,
#      'acesBefore15Minutes': 3,
#      'alliedJungleMonsterKills': 0,
#      'baronTakedowns': 0,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 600,
#      'buffsStolen': 0,
#      'completeSupportQuestInTime': 0,
#      'controlWardsPlaced': 0,
#      'damagePerMinute': 2437.031095713721,
#      'damageTakenOnTeamPercentage': 0.1783940402534787,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 10,
#      'dodgeSkillShotsSmallWindow': 3,
#      'doubleAces': 0,
#      'dragonTakedowns': 0,
#      'earlyLaningPhaseGoldExpAdvantage': 0,
#      'effectiveHealAndShielding': 0,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 0,
#      'enemyJungleMonsterKills': 0,
#      'epicMonsterKillsNearEnemyJungler': 0,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'flawlessAces': 1,
#      'fullTeamTakedown': 18,
#      'gameLength': 989.7760772800383,
#      'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#      'goldPerMinute': 824.8463094549633,
#      'hadOpenNexus': 0,
#      'highestChampionDamage': 1,
#      'highestCrowdControlScore': 1,
#      'immobilizeAndKillWithAlly': 0,
#      'initialBuffCount': 0,
#      'initialCrabCount': 0,
#      'jungleCsBefore10Minutes': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 0,
#      'kTurretsDestroyedBeforePlatesFall': 1,
#      'kda': 4.8,
#      'killAfterHiddenWithAlly': 3,
#      'killParticipation': 0.8135593220338984,
#      'killedChampTookFullTeamDamageSurvived': 0,
#      'killingSprees': 2,
#      'killsNearEnemyTurret': 5,
#      'killsOnOtherLanesEarlyJungleAsLaner': 0,
#      'killsOnRecentlyHealedByAramPack': 1,
#      'killsUnderOwnTurret': 3,
#      'killsWithHelpFromEpicMonster': 0,
#      'knockEnemyIntoTeamAndKill': 0,
#      'landSkillShotsEarlyGame': 9,
#      'laneMinionsFirst10Minutes': 29,
#      'laningPhaseGoldExpAdvantage': 0,
#      'legendaryCount': 0,
#      'lostAnInhibitor': 0,
#      'maxCsAdvantageOnLaneOpponent': 6,
#      'maxKillDeficit': 1,
#      'maxLevelLeadLaneOpponent': 2,
#      'moreEnemyJungleThanOpponent': 0,
#      'multiKillOneSpell': 0,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 3,
#      'multikillsAfterAggressiveFlash': 0,
#      'mythicItemUsed': 6655,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 0,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 30,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 0,
#      'saveAllyFromDeath': 0,
#      'scuttleCrabKills': 0,
#      'shortestTimeToAceFromFirstTakedown': 7.038250364849546,
#      'skillshotsDodged': 23,
#      'skillshotsHit': 31,
#      'snowballsHit': 5,
#      'soloBaronKills': 0,
#      'soloKills': 0,
#      'stealthWardsPlaced': 0,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 1,
#      'takedownOnFirstTurret': 1,
#      'takedowns': 48,
#      'takedownsAfterGainingLevelAdvantage': 1,
#      'takedownsBeforeJungleMinionSpawn': 3,
#      'takedownsFirstXMinutes': 43,
#      'takedownsInAlcove': 0,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 0,
#      'teamDamagePercentage': 0.31603611622512634,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 0,
#      'threeWardsOneSweeperCount': 0,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 0,
#      'turretTakedowns': 2,
#      'turretsTakenWithRiftHerald': 0,
#      'twentyMinionsIn3SecondsCount': 1,
#      'unseenRecalls': 0,
#      'visionScoreAdvantageLaneOpponent': -1,
#      'visionScorePerMinute': 0,
#      'wardTakedowns': 0,
#      'wardTakedownsBefore20M': 0,
#      'wardsGuarded': 0},
#     'champExperience': 17167,
#     'champLevel': 17,
#     'championId': 30,
#     'championName': 'Karthus',
#     'championTransform': 0,
#     'commandPings': 0,
#     'consumablesPurchased': 2,
#     'damageDealtToBuildings': 1085,
#     'damageDealtToObjectives': 1085,
#     'damageDealtToTurrets': 1085,
#     'damageSelfMitigated': 9444,
#     'dangerPings': 0,
#     'deaths': 10,
#     'detectorWardsPlaced': 0,
#     'doubleKills': 3,
#     'dragonKills': 0,
#     'eligibleForProgression': True,
#     'enemyMissingPings': 2,
#     'enemyVisionPings': 0,
#     'firstBloodAssist': True,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'getBackPings': 0,
#     'goldEarned': 13606,
#     'goldSpent': 12450,
#     'holdPings': 0,
#     'individualPosition': 'Invalid',
#     'inhibitorKills': 1,
#     'inhibitorTakedowns': 1,
#     'inhibitorsLost': 0,
#     'item0': 6655,
#     'item1': 3070,
#     'item2': 3020,
#     'item3': 3089,
#     'item4': 3135,
#     'item5': 1058,
#     'item6': 2052,
#     'itemsPurchased': 16,
#     'killingSprees': 4,
#     'kills': 14,
#     'lane': 'NONE',
#     'largestCriticalStrike': 0,
#     'largestKillingSpree': 4,
#     'largestMultiKill': 2,
#     'longestTimeSpentLiving': 102,
#     'magicDamageDealt': 84636,
#     'magicDamageDealtToChampions': 38843,
#     'magicDamageTaken': 4151,
#     'needVisionPings': 0,
#     'neutralMinionsKilled': 0,
#     'nexusKills': 0,
#     'nexusLost': 0,
#     'nexusTakedowns': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'onMyWayPings': 0,
#     'participantId': 4,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5002, 'flex': 5008, 'offense': 5007},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8128, 'var1': 2968, 'var2': 36, 'var3': 0},
#         {'perk': 8139, 'var1': 1274, 'var2': 0, 'var3': 0},
#         {'perk': 8138, 'var1': 30, 'var2': 0, 'var3': 0},
#         {'perk': 8106, 'var1': 5, 'var2': 0, 'var3': 0}],
#        'style': 8100},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8014, 'var1': 919, 'var2': 0, 'var3': 0},
#         {'perk': 8009, 'var1': 8188, 'var2': 0, 'var3': 0}],
#        'style': 8000}]},
#     'physicalDamageDealt': 269,
#     'physicalDamageDealtToChampions': 189,
#     'physicalDamageTaken': 12698,
#     'profileIcon': 1114,
#     'pushPings': 0,
#     'puuid': 'fA7mCb6WNZMiqvzulHyfV30dyQZIKH9DDqyn4HRrRl7yI8c7Y2Qt68Wo7Ofy2Es45Tf8mLMag5jnhw',
#     'quadraKills': 0,
#     'riotIdName': '',
#     'riotIdTagline': '',
#     'role': 'SUPPORT',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 212,
#     'spell2Casts': 33,
#     'spell3Casts': 50,
#     'spell4Casts': 5,
#     'summoner1Casts': 16,
#     'summoner1Id': 32,
#     'summoner2Casts': 2,
#     'summoner2Id': 4,
#     'summonerId': '6GjqAnNOocimj4x14AiuyO7KJYVM4UTsqojp6I0zKAFaAyA',
#     'summonerLevel': 309,
#     'summonerName': 'FreezingFire723',
#     'teamEarlySurrendered': False,
#     'teamId': 100,
#     'teamPosition': '',
#     'timeCCingOthers': 32,
#     'timePlayed': 989,
#     'totalDamageDealt': 86224,
#     'totalDamageDealtToChampions': 40201,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 19196,
#     'totalHeal': 1792,
#     'totalHealsOnTeammates': 0,
#     'totalMinionsKilled': 51,
#     'totalTimeCCDealt': 241,
#     'totalTimeSpentDead': 281,
#     'totalUnitsHealed': 1,
#     'tripleKills': 0,
#     'trueDamageDealt': 1318,
#     'trueDamageDealtToChampions': 1168,
#     'trueDamageTaken': 2346,
#     'turretKills': 0,
#     'turretTakedowns': 2,
#     'turretsLost': 1,
#     'unrealKills': 0,
#     'visionClearedPings': 0,
#     'visionScore': 0,
#     'visionWardsBoughtInGame': 0,
#     'wardsKilled': 0,
#     'wardsPlaced': 0,
#     'win': True},
#    {'allInPings': 0,
#     'assistMePings': 1,
#     'assists': 24,
#     'baitPings': 0,
#     'baronKills': 0,
#     'basicPings': 0,
#     'bountyLevel': 5,
#     'challenges': {'12AssistStreakCount': 0,
#      'abilityUses': 116,
#      'acesBefore15Minutes': 3,
#      'alliedJungleMonsterKills': 0,
#      'baronTakedowns': 0,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 1050,
#      'buffsStolen': 0,
#      'completeSupportQuestInTime': 0,
#      'controlWardsPlaced': 0,
#      'damagePerMinute': 2028.4699354851664,
#      'damageTakenOnTeamPercentage': 0.18169013294564215,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 7,
#      'dodgeSkillShotsSmallWindow': 3,
#      'doubleAces': 0,
#      'dragonTakedowns': 0,
#      'earlyLaningPhaseGoldExpAdvantage': 0,
#      'effectiveHealAndShielding': 0,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 0,
#      'enemyJungleMonsterKills': 0,
#      'epicMonsterKillsNearEnemyJungler': 0,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'flawlessAces': 1,
#      'fullTeamTakedown': 18,
#      'gameLength': 989.7760772800383,
#      'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#      'goldPerMinute': 975.4428128740666,
#      'hadOpenNexus': 0,
#      'immobilizeAndKillWithAlly': 0,
#      'initialBuffCount': 0,
#      'initialCrabCount': 0,
#      'jungleCsBefore10Minutes': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 0,
#      'kTurretsDestroyedBeforePlatesFall': 1,
#      'kda': 6.428571428571429,
#      'killAfterHiddenWithAlly': 0,
#      'killParticipation': 0.7627118644067796,
#      'killedChampTookFullTeamDamageSurvived': 0,
#      'killingSprees': 5,
#      'killsNearEnemyTurret': 5,
#      'killsOnOtherLanesEarlyJungleAsLaner': 0,
#      'killsOnRecentlyHealedByAramPack': 0,
#      'killsUnderOwnTurret': 4,
#      'killsWithHelpFromEpicMonster': 0,
#      'knockEnemyIntoTeamAndKill': 0,
#      'landSkillShotsEarlyGame': 6,
#      'laneMinionsFirst10Minutes': 40,
#      'laningPhaseGoldExpAdvantage': 0,
#      'legendaryCount': 0,
#      'lostAnInhibitor': 0,
#      'maxCsAdvantageOnLaneOpponent': 26,
#      'maxKillDeficit': 1,
#      'maxLevelLeadLaneOpponent': 2,
#      'moreEnemyJungleThanOpponent': 0,
#      'multiKillOneSpell': 0,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 5,
#      'multikillsAfterAggressiveFlash': 0,
#      'mythicItemUsed': 6672,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 3,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 28,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 0,
#      'saveAllyFromDeath': 0,
#      'scuttleCrabKills': 0,
#      'shortestTimeToAceFromFirstTakedown': 7.038250364849546,
#      'skillshotsDodged': 20,
#      'skillshotsHit': 19,
#      'snowballsHit': 0,
#      'soloBaronKills': 0,
#      'soloKills': 1,
#      'stealthWardsPlaced': 0,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 4,
#      'takedownOnFirstTurret': 0,
#      'takedowns': 45,
#      'takedownsAfterGainingLevelAdvantage': 1,
#      'takedownsBeforeJungleMinionSpawn': 3,
#      'takedownsFirstXMinutes': 40,
#      'takedownsInAlcove': 0,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 0,
#      'teamDamagePercentage': 0.2630535824584617,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 0,
#      'threeWardsOneSweeperCount': 0,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 0,
#      'turretTakedowns': 4,
#      'turretsTakenWithRiftHerald': 0,
#      'twentyMinionsIn3SecondsCount': 3,
#      'unseenRecalls': 0,
#      'visionScoreAdvantageLaneOpponent': -1,
#      'visionScorePerMinute': 0,
#      'wardTakedowns': 0,
#      'wardTakedownsBefore20M': 0,
#      'wardsGuarded': 0},
#     'champExperience': 16104,
#     'champLevel': 16,
#     'championId': 236,
#     'championName': 'Lucian',
#     'championTransform': 0,
#     'commandPings': 0,
#     'consumablesPurchased': 0,
#     'damageDealtToBuildings': 5102,
#     'damageDealtToObjectives': 5102,
#     'damageDealtToTurrets': 5102,
#     'damageSelfMitigated': 12672,
#     'dangerPings': 0,
#     'deaths': 7,
#     'detectorWardsPlaced': 0,
#     'doubleKills': 3,
#     'dragonKills': 0,
#     'eligibleForProgression': True,
#     'enemyMissingPings': 0,
#     'enemyVisionPings': 0,
#     'firstBloodAssist': False,
#     'firstBloodKill': True,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'getBackPings': 0,
#     'goldEarned': 16091,
#     'goldSpent': 13700,
#     'holdPings': 0,
#     'individualPosition': 'Invalid',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 1,
#     'inhibitorsLost': 0,
#     'item0': 3072,
#     'item1': 3006,
#     'item2': 1038,
#     'item3': 6672,
#     'item4': 3508,
#     'item5': 1018,
#     'item6': 2052,
#     'itemsPurchased': 15,
#     'killingSprees': 5,
#     'kills': 21,
#     'lane': 'NONE',
#     'largestCriticalStrike': 549,
#     'largestKillingSpree': 5,
#     'largestMultiKill': 3,
#     'longestTimeSpentLiving': 179,
#     'magicDamageDealt': 4052,
#     'magicDamageDealtToChampions': 2866,
#     'magicDamageTaken': 5978,
#     'needVisionPings': 0,
#     'neutralMinionsKilled': 0,
#     'nexusKills': 1,
#     'nexusLost': 0,
#     'nexusTakedowns': 1,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'onMyWayPings': 3,
#     'participantId': 5,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5002, 'flex': 5008, 'offense': 5005},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8005, 'var1': 1388, 'var2': 869, 'var3': 519},
#         {'perk': 8009, 'var1': 2453, 'var2': 0, 'var3': 0},
#         {'perk': 9104, 'var1': 3, 'var2': 20, 'var3': 0},
#         {'perk': 8014, 'var1': 1104, 'var2': 0, 'var3': 0}],
#        'style': 8000},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8139, 'var1': 1091, 'var2': 0, 'var3': 0},
#         {'perk': 8135, 'var1': 550, 'var2': 5, 'var3': 0}],
#        'style': 8100}]},
#     'physicalDamageDealt': 75068,
#     'physicalDamageDealtToChampions': 28488,
#     'physicalDamageTaken': 12636,
#     'profileIcon': 5551,
#     'pushPings': 0,
#     'puuid': 'fq3n5PJ7YoapfPW7r4jMszpA0dJe78xaf9aOGgbQo5Z1MZiccFT_2xgGwFJR1G8ABPmRex2AkvvuBg',
#     'quadraKills': 0,
#     'riotIdName': '',
#     'riotIdTagline': '',
#     'role': 'DUO',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 40,
#     'spell2Casts': 30,
#     'spell3Casts': 38,
#     'spell4Casts': 8,
#     'summoner1Casts': 4,
#     'summoner1Id': 4,
#     'summoner2Casts': 6,
#     'summoner2Id': 6,
#     'summonerId': 'jESyRZzdf1TB0T1i0zKK-Ih7LcOzHOEJ3XwFZelSO9lvF5o',
#     'summonerLevel': 293,
#     'summonerName': 'Wiizzon',
#     'teamEarlySurrendered': False,
#     'teamId': 100,
#     'teamPosition': '',
#     'timeCCingOthers': 0,
#     'timePlayed': 989,
#     'totalDamageDealt': 83796,
#     'totalDamageDealtToChampions': 33462,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 19550,
#     'totalHeal': 2733,
#     'totalHealsOnTeammates': 0,
#     'totalMinionsKilled': 79,
#     'totalTimeCCDealt': 38,
#     'totalTimeSpentDead': 191,
#     'totalUnitsHealed': 1,
#     'tripleKills': 2,
#     'trueDamageDealt': 4675,
#     'trueDamageDealtToChampions': 2107,
#     'trueDamageTaken': 936,
#     'turretKills': 1,
#     'turretTakedowns': 4,
#     'turretsLost': 1,
#     'unrealKills': 0,
#     'visionClearedPings': 0,
#     'visionScore': 0,
#     'visionWardsBoughtInGame': 0,
#     'wardsKilled': 0,
#     'wardsPlaced': 0,
#     'win': True},
#    {'allInPings': 0,
#     'assistMePings': 0,
#     'assists': 24,
#     'baitPings': 0,
#     'baronKills': 0,
#     'basicPings': 0,
#     'bountyLevel': 0,
#     'challenges': {'12AssistStreakCount': 0,
#      'abilityUses': 123,
#      'acesBefore15Minutes': 2,
#      'alliedJungleMonsterKills': 0,
#      'baronTakedowns': 0,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 150,
#      'buffsStolen': 0,
#      'completeSupportQuestInTime': 0,
#      'controlWardsPlaced': 0,
#      'damagePerMinute': 1185.8233759300329,
#      'damageTakenOnTeamPercentage': 0.1532762322444143,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 9,
#      'dodgeSkillShotsSmallWindow': 3,
#      'doubleAces': 0,
#      'dragonTakedowns': 0,
#      'earlyLaningPhaseGoldExpAdvantage': 0,
#      'effectiveHealAndShielding': 443.75,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 0,
#      'enemyJungleMonsterKills': 0,
#      'epicMonsterKillsNearEnemyJungler': 0,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'firstTurretKilledTime': 405.0710904275439,
#      'flawlessAces': 0,
#      'fullTeamTakedown': 6,
#      'gameLength': 989.7760772800383,
#      'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#      'goldPerMinute': 673.0061535287366,
#      'hadOpenNexus': 0,
#      'immobilizeAndKillWithAlly': 0,
#      'initialBuffCount': 0,
#      'initialCrabCount': 0,
#      'jungleCsBefore10Minutes': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 0,
#      'kTurretsDestroyedBeforePlatesFall': 1,
#      'kda': 2.8,
#      'killAfterHiddenWithAlly': 1,
#      'killParticipation': 0.7,
#      'killedChampTookFullTeamDamageSurvived': 0,
#      'killsNearEnemyTurret': 0,
#      'killsOnOtherLanesEarlyJungleAsLaner': 0,
#      'killsOnRecentlyHealedByAramPack': 0,
#      'killsUnderOwnTurret': 2,
#      'killsWithHelpFromEpicMonster': 0,
#      'knockEnemyIntoTeamAndKill': 0,
#      'landSkillShotsEarlyGame': 27,
#      'laneMinionsFirst10Minutes': 33,
#      'laningPhaseGoldExpAdvantage': 0,
#      'legendaryCount': 0,
#      'lostAnInhibitor': 0,
#      'maxCsAdvantageOnLaneOpponent': 7,
#      'maxKillDeficit': 0,
#      'maxLevelLeadLaneOpponent': 1,
#      'moreEnemyJungleThanOpponent': 0,
#      'multiKillOneSpell': 0,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 0,
#      'multikillsAfterAggressiveFlash': 0,
#      'mythicItemUsed': 6672,
#      'outerTurretExecutesBefore10Minutes': 1,
#      'outnumberedKills': 0,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 20,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 0,
#      'saveAllyFromDeath': 0,
#      'scuttleCrabKills': 0,
#      'shortestTimeToAceFromFirstTakedown': 9.751264095505917,
#      'skillshotsDodged': 21,
#      'skillshotsHit': 71,
#      'snowballsHit': 0,
#      'soloBaronKills': 0,
#      'soloKills': 0,
#      'stealthWardsPlaced': 0,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 0,
#      'takedownOnFirstTurret': 1,
#      'takedowns': 28,
#      'takedownsAfterGainingLevelAdvantage': 0,
#      'takedownsBeforeJungleMinionSpawn': 3,
#      'takedownsFirstXMinutes': 26,
#      'takedownsInAlcove': 0,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 0,
#      'teamDamagePercentage': 0.20322991365959567,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 0,
#      'threeWardsOneSweeperCount': 0,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 0,
#      'turretTakedowns': 1,
#      'turretsTakenWithRiftHerald': 0,
#      'twentyMinionsIn3SecondsCount': 2,
#      'unseenRecalls': 0,
#      'visionScoreAdvantageLaneOpponent': -1,
#      'visionScorePerMinute': 0,
#      'wardTakedowns': 0,
#      'wardTakedownsBefore20M': 0,
#      'wardsGuarded': 0},
#     'champExperience': 14824,
#     'champLevel': 16,
#     'championId': 15,
#     'championName': 'Sivir',
#     'championTransform': 0,
#     'commandPings': 0,
#     'consumablesPurchased': 2,
#     'damageDealtToBuildings': 727,
#     'damageDealtToObjectives': 727,
#     'damageDealtToTurrets': 727,
#     'damageSelfMitigated': 5833,
#     'dangerPings': 0,
#     'deaths': 10,
#     'detectorWardsPlaced': 0,
#     'doubleKills': 0,
#     'dragonKills': 0,
#     'eligibleForProgression': True,
#     'enemyMissingPings': 0,
#     'enemyVisionPings': 0,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': True,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'getBackPings': 0,
#     'goldEarned': 11102,
#     'goldSpent': 9750,
#     'holdPings': 0,
#     'individualPosition': 'Invalid',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 0,
#     'inhibitorsLost': 1,
#     'item0': 6672,
#     'item1': 3006,
#     'item2': 3070,
#     'item3': 3153,
#     'item4': 3133,
#     'item5': 1036,
#     'item6': 2052,
#     'itemsPurchased': 16,
#     'killingSprees': 0,
#     'kills': 4,
#     'lane': 'NONE',
#     'largestCriticalStrike': 394,
#     'largestKillingSpree': 0,
#     'largestMultiKill': 1,
#     'longestTimeSpentLiving': 121,
#     'magicDamageDealt': 98,
#     'magicDamageDealtToChampions': 98,
#     'magicDamageTaken': 14951,
#     'needVisionPings': 0,
#     'neutralMinionsKilled': 0,
#     'nexusKills': 0,
#     'nexusLost': 1,
#     'nexusTakedowns': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'onMyWayPings': 0,
#     'participantId': 6,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5002, 'flex': 5008, 'offense': 5005},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8008, 'var1': 62, 'var2': 7, 'var3': 0},
#         {'perk': 8009, 'var1': 2785, 'var2': 0, 'var3': 0},
#         {'perk': 9103, 'var1': 8, 'var2': 20, 'var3': 0},
#         {'perk': 8014, 'var1': 424, 'var2': 0, 'var3': 0}],
#        'style': 8000},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8139, 'var1': 855, 'var2': 0, 'var3': 0},
#         {'perk': 8135, 'var1': 550, 'var2': 5, 'var3': 0}],
#        'style': 8100}]},
#     'physicalDamageDealt': 56376,
#     'physicalDamageDealtToChampions': 18326,
#     'physicalDamageTaken': 4268,
#     'profileIcon': 4568,
#     'pushPings': 0,
#     'puuid': 'KYrJq363rjMUXOT26AaC0ATaZpRvUkXDQ2dXl_CT71HzetUZXMkD3Dq0VJXxdn434KEwhd6QzA49Ow',
#     'quadraKills': 0,
#     'riotIdName': '',
#     'riotIdTagline': '',
#     'role': 'SUPPORT',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 55,
#     'spell2Casts': 44,
#     'spell3Casts': 18,
#     'spell4Casts': 6,
#     'summoner1Casts': 5,
#     'summoner1Id': 7,
#     'summoner2Casts': 5,
#     'summoner2Id': 4,
#     'summonerId': 'wxNyp3947mo7zKCQnk4_b2jgTJCcVuzrEhlNrTfLY7CtDBY',
#     'summonerLevel': 386,
#     'summonerName': 'GrudgeAwall',
#     'teamEarlySurrendered': False,
#     'teamId': 200,
#     'teamPosition': '',
#     'timeCCingOthers': 0,
#     'timePlayed': 989,
#     'totalDamageDealt': 58285,
#     'totalDamageDealtToChampions': 19561,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 20125,
#     'totalHeal': 3292,
#     'totalHealsOnTeammates': 443,
#     'totalMinionsKilled': 53,
#     'totalTimeCCDealt': 3,
#     'totalTimeSpentDead': 276,
#     'totalUnitsHealed': 3,
#     'tripleKills': 0,
#     'trueDamageDealt': 1810,
#     'trueDamageDealtToChampions': 1137,
#     'trueDamageTaken': 906,
#     'turretKills': 1,
#     'turretTakedowns': 1,
#     'turretsLost': 4,
#     'unrealKills': 0,
#     'visionClearedPings': 0,
#     'visionScore': 0,
#     'visionWardsBoughtInGame': 0,
#     'wardsKilled': 0,
#     'wardsPlaced': 0,
#     'win': False},
#    {'allInPings': 0,
#     'assistMePings': 0,
#     'assists': 15,
#     'baitPings': 0,
#     'baronKills': 0,
#     'basicPings': 0,
#     'bountyLevel': 1,
#     'challenges': {'12AssistStreakCount': 0,
#      'abilityUses': 105,
#      'acesBefore15Minutes': 2,
#      'alliedJungleMonsterKills': 0,
#      'baronTakedowns': 0,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 1275,
#      'buffsStolen': 0,
#      'completeSupportQuestInTime': 0,
#      'controlWardsPlaced': 0,
#      'damagePerMinute': 1215.3191572690075,
#      'damageTakenOnTeamPercentage': 0.3143357231064254,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 16,
#      'dodgeSkillShotsSmallWindow': 9,
#      'doubleAces': 0,
#      'dragonTakedowns': 0,
#      'earlyLaningPhaseGoldExpAdvantage': 0,
#      'effectiveHealAndShielding': 0,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 30,
#      'enemyJungleMonsterKills': 0,
#      'epicMonsterKillsNearEnemyJungler': 0,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 0,
# ...
#     'win': False},
#    {'allInPings': 0,
#     'assistMePings': 0,
#     'assists': 11,
#     'baitPings': 0,
#     'baronKills': 0,
#     'basicPings': 0,
#     'bountyLevel': 0,
#     'challenges': {'12AssistStreakCount': 0,
#      'abilityUses': 90,
#      'acesBefore15Minutes': 2,
#      'alliedJungleMonsterKills': 0,
#      'baronTakedowns': 0,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 150,
#      'buffsStolen': 0,
#      'completeSupportQuestInTime': 0,
#      'controlWardsPlaced': 0,
#      'damagePerMinute': 745.1337958131758,
#      'damageTakenOnTeamPercentage': 0.21841342033261668,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 16,
#      'dodgeSkillShotsSmallWindow': 7,
#      'doubleAces': 0,
#      'dragonTakedowns': 0,
#      'earlyLaningPhaseGoldExpAdvantage': 0,
#      'effectiveHealAndShielding': 0,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 24,
#      'enemyJungleMonsterKills': 0,
#      'epicMonsterKillsNearEnemyJungler': 0,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'firstTurretKilledTime': 405.0710904275439,
#      'flawlessAces': 0,
#      'fullTeamTakedown': 6,
#      'gameLength': 989.7760772800383,
#      'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#      'goldPerMinute': 559.7342026693104,
#      'hadOpenNexus': 0,
#      'immobilizeAndKillWithAlly': 7,
#      'initialBuffCount': 0,
#      'initialCrabCount': 0,
#      'jungleCsBefore10Minutes': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 0,
#      'kTurretsDestroyedBeforePlatesFall': 0,
#      'kda': 1,
#      'killAfterHiddenWithAlly': 0,
#      'killParticipation': 0.4,
#      'killedChampTookFullTeamDamageSurvived': 0,
#      'killsNearEnemyTurret': 1,
#      'killsOnOtherLanesEarlyJungleAsLaner': 0,
#      'killsOnRecentlyHealedByAramPack': 0,
#      'killsUnderOwnTurret': 1,
#      'killsWithHelpFromEpicMonster': 0,
#      'knockEnemyIntoTeamAndKill': 0,
#      'landSkillShotsEarlyGame': 0,
#      'laneMinionsFirst10Minutes': 5,
#      'laningPhaseGoldExpAdvantage': 0,
#      'legendaryCount': 0,
#      'lostAnInhibitor': 0,
#      'maxCsAdvantageOnLaneOpponent': 0,
#      'maxKillDeficit': 0,
#      'maxLevelLeadLaneOpponent': 1,
#      'moreEnemyJungleThanOpponent': 0,
#      'multiKillOneSpell': 0,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 0,
#      'multikillsAfterAggressiveFlash': 0,
#      'mythicItemUsed': 6632,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 2,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 12,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 0,
#      'saveAllyFromDeath': 0,
#      'scuttleCrabKills': 0,
#      'shortestTimeToAceFromFirstTakedown': 9.751264095505917,
#      'skillshotsDodged': 39,
#      'skillshotsHit': 0,
#      'snowballsHit': 5,
#      'soloBaronKills': 0,
#      'soloKills': 0,
#      'stealthWardsPlaced': 0,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 0,
#      'takedownOnFirstTurret': 0,
#      'takedowns': 16,
#      'takedownsAfterGainingLevelAdvantage': 0,
#      'takedownsBeforeJungleMinionSpawn': 3,
#      'takedownsFirstXMinutes': 14,
#      'takedownsInAlcove': 0,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 0,
#      'teamDamagePercentage': 0.12770323141015016,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 0,
#      'threeWardsOneSweeperCount': 0,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 0,
#      'turretTakedowns': 0,
#      'turretsTakenWithRiftHerald': 0,
#      'twentyMinionsIn3SecondsCount': 0,
#      'unseenRecalls': 0,
#      'visionScoreAdvantageLaneOpponent': -1,
#      'visionScorePerMinute': 0,
#      'wardTakedowns': 0,
#      'wardTakedownsBefore20M': 0,
#      'wardsGuarded': 0},
#     'champExperience': 11361,
#     'champLevel': 13,
#     'championId': 24,
#     'championName': 'Jax',
#     'championTransform': 0,
#     'commandPings': 0,
#     'consumablesPurchased': 1,
#     'damageDealtToBuildings': 0,
#     'damageDealtToObjectives': 0,
#     'damageDealtToTurrets': 0,
#     'damageSelfMitigated': 24365,
#     'dangerPings': 0,
#     'deaths': 16,
#     'detectorWardsPlaced': 0,
#     'doubleKills': 0,
#     'dragonKills': 0,
#     'eligibleForProgression': True,
#     'enemyMissingPings': 0,
#     'enemyVisionPings': 0,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'getBackPings': 0,
#     'goldEarned': 9233,
#     'goldSpent': 8950,
#     'holdPings': 0,
#     'individualPosition': 'Invalid',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 0,
#     'inhibitorsLost': 1,
#     'item0': 6632,
#     'item1': 3091,
#     'item2': 1029,
#     'item3': 3133,
#     'item4': 0,
#     'item5': 3111,
#     'item6': 2052,
#     'itemsPurchased': 20,
#     'killingSprees': 0,
#     'kills': 5,
#     'lane': 'NONE',
#     'largestCriticalStrike': 0,
#     'largestKillingSpree': 0,
#     'largestMultiKill': 1,
#     'longestTimeSpentLiving': 82,
#     'magicDamageDealt': 7918,
#     'magicDamageDealtToChampions': 4614,
#     'magicDamageTaken': 17841,
#     'needVisionPings': 0,
#     'neutralMinionsKilled': 0,
#     'nexusKills': 0,
#     'nexusLost': 1,
#     'nexusTakedowns': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'onMyWayPings': 0,
#     'participantId': 9,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5002, 'flex': 5008, 'offense': 5005},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8008, 'var1': 5, 'var2': 1, 'var3': 0},
#         {'perk': 9111, 'var1': 292, 'var2': 160, 'var3': 0},
#         {'perk': 9105, 'var1': 11, 'var2': 0, 'var3': 0},
#         {'perk': 8299, 'var1': 456, 'var2': 0, 'var3': 0}],
#        'style': 8000},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8429, 'var1': 51, 'var2': 11, 'var3': 12},
#         {'perk': 8242, 'var1': 117, 'var2': 0, 'var3': 0}],
#        'style': 8400}]},
#     'physicalDamageDealt': 10818,
#     'physicalDamageDealtToChampions': 7157,
#     'physicalDamageTaken': 9677,
#     'profileIcon': 4549,
#     'pushPings': 0,
#     'puuid': 'aRrSlfzQHMgyHguY2QWUrWTLz8zUvPRVurC0xeAUQvmFB3B_Wd9WH1VKmQak30zrZsri-fGPMwSb3w',
#     'quadraKills': 0,
#     'riotIdName': '',
#     'riotIdTagline': '',
#     'role': 'SUPPORT',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 21,
#     'spell2Casts': 23,
#     'spell3Casts': 38,
#     'spell4Casts': 8,
#     'summoner1Casts': 4,
#     'summoner1Id': 4,
#     'summoner2Casts': 12,
#     'summoner2Id': 32,
#     'summonerId': '8Om8zPYUocOTKqCcVwpiQtFTAxVbZ1jWz-iLPSmc3VYtdBI',
#     'summonerLevel': 209,
#     'summonerName': 'Astro696',
#     'teamEarlySurrendered': False,
#     'teamId': 200,
#     'teamPosition': '',
#     'timeCCingOthers': 22,
#     'timePlayed': 989,
#     'totalDamageDealt': 19256,
#     'totalDamageDealtToChampions': 12291,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 28678,
#     'totalHeal': 2279,
#     'totalHealsOnTeammates': 0,
#     'totalMinionsKilled': 10,
#     'totalTimeCCDealt': 55,
#     'totalTimeSpentDead': 405,
#     'totalUnitsHealed': 1,
#     'tripleKills': 0,
#     'trueDamageDealt': 520,
#     'trueDamageDealtToChampions': 520,
#     'trueDamageTaken': 1159,
#     'turretKills': 0,
#     'turretTakedowns': 0,
#     'turretsLost': 4,
#     'unrealKills': 0,
#     'visionClearedPings': 0,
#     'visionScore': 0,
#     'visionWardsBoughtInGame': 0,
#     'wardsKilled': 0,
#     'wardsPlaced': 0,
#     'win': False},
#    {'allInPings': 0,
#     'assistMePings': 0,
#     'assists': 19,
#     'baitPings': 0,
#     'baronKills': 0,
#     'basicPings': 0,
#     'bountyLevel': 0,
#     'challenges': {'12AssistStreakCount': 0,
#      'abilityUses': 63,
#      'acesBefore15Minutes': 2,
#      'alliedJungleMonsterKills': 0,
#      'baronTakedowns': 0,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 675,
#      'buffsStolen': 0,
#      'completeSupportQuestInTime': 0,
#      'controlWardsPlaced': 0,
#      'damagePerMinute': 1260.4853864305067,
#      'damageTakenOnTeamPercentage': 0.1390587780652566,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 9,
#      'dodgeSkillShotsSmallWindow': 2,
#      'doubleAces': 0,
#      'dragonTakedowns': 0,
#      'earlyLaningPhaseGoldExpAdvantage': 0,
#      'effectiveHealAndShielding': 0,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 3,
#      'enemyJungleMonsterKills': 0,
#      'epicMonsterKillsNearEnemyJungler': 0,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'firstTurretKilledTime': 405.0710904275439,
#      'flawlessAces': 0,
#      'fullTeamTakedown': 6,
#      'gameLength': 989.7760772800383,
#      'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#      'goldPerMinute': 750.7469854110873,
#      'hadOpenNexus': 0,
#      'immobilizeAndKillWithAlly': 1,
#      'initialBuffCount': 0,
#      'initialCrabCount': 0,
#      'jungleCsBefore10Minutes': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 0,
#      'kTurretsDestroyedBeforePlatesFall': 1,
#      'kda': 3.111111111111111,
#      'killAfterHiddenWithAlly': 4,
#      'killParticipation': 0.7,
#      'killedChampTookFullTeamDamageSurvived': 0,
#      'killingSprees': 1,
#      'killsNearEnemyTurret': 0,
#      'killsOnOtherLanesEarlyJungleAsLaner': 0,
#      'killsOnRecentlyHealedByAramPack': 0,
#      'killsUnderOwnTurret': 4,
#      'killsWithHelpFromEpicMonster': 0,
#      'knockEnemyIntoTeamAndKill': 1,
#      'landSkillShotsEarlyGame': 0,
#      'laneMinionsFirst10Minutes': 37,
#      'laningPhaseGoldExpAdvantage': 0,
#      'legendaryCount': 0,
#      'lostAnInhibitor': 0,
#      'maxCsAdvantageOnLaneOpponent': 20,
#      'maxKillDeficit': 0,
#      'maxLevelLeadLaneOpponent': 1,
#      'moreEnemyJungleThanOpponent': 0,
#      'multiKillOneSpell': 0,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 3,
#      'multikillsAfterAggressiveFlash': 0,
#      'mythicItemUsed': 6672,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 5,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 18,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 0,
#      'saveAllyFromDeath': 0,
#      'scuttleCrabKills': 0,
#      'shortestTimeToAceFromFirstTakedown': 9.751264095505917,
#      'skillshotsDodged': 15,
#      'skillshotsHit': 0,
#      'snowballsHit': 0,
#      'soloBaronKills': 0,
#      'soloKills': 0,
#      'stealthWardsPlaced': 0,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 0,
#      'takedownOnFirstTurret': 0,
#      'takedowns': 28,
#      'takedownsAfterGainingLevelAdvantage': 2,
#      'takedownsBeforeJungleMinionSpawn': 2,
#      'takedownsFirstXMinutes': 27,
#      'takedownsInAlcove': 0,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 0,
#      'teamDamagePercentage': 0.21602570960666292,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 0,
#      'threeWardsOneSweeperCount': 0,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 0,
#      'turretTakedowns': 1,
#      'turretsTakenWithRiftHerald': 0,
#      'twentyMinionsIn3SecondsCount': 2,
#      'unseenRecalls': 0,
#      'visionScoreAdvantageLaneOpponent': -1,
#      'visionScorePerMinute': 0,
#      'wardTakedowns': 0,
#      'wardTakedownsBefore20M': 0,
#      'wardsGuarded': 0},
#     'champExperience': 16996,
#     'champLevel': 17,
#     'championId': 18,
#     'championName': 'Tristana',
#     'championTransform': 0,
#     'commandPings': 0,
#     'consumablesPurchased': 2,
#     'damageDealtToBuildings': 2482,
#     'damageDealtToObjectives': 2482,
#     'damageDealtToTurrets': 2482,
#     'damageSelfMitigated': 6885,
#     'dangerPings': 0,
#     'deaths': 9,
#     'detectorWardsPlaced': 0,
#     'doubleKills': 2,
#     'dragonKills': 0,
#     'eligibleForProgression': True,
#     'enemyMissingPings': 0,
#     'enemyVisionPings': 0,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': True,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'getBackPings': 0,
#     'goldEarned': 12384,
#     'goldSpent': 11800,
#     'holdPings': 0,
#     'individualPosition': 'Invalid',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 0,
#     'inhibitorsLost': 1,
#     'item0': 6672,
#     'item1': 3153,
#     'item2': 3006,
#     'item3': 3036,
#     'item4': 1053,
#     'item5': 0,
#     'item6': 2052,
#     'itemsPurchased': 17,
#     'killingSprees': 4,
#     'kills': 9,
#     'lane': 'NONE',
#     'largestCriticalStrike': 468,
#     'largestKillingSpree': 3,
#     'largestMultiKill': 3,
#     'longestTimeSpentLiving': 149,
#     'magicDamageDealt': 7803,
#     'magicDamageDealtToChampions': 1079,
#     'magicDamageTaken': 11957,
#     'needVisionPings': 0,
#     'neutralMinionsKilled': 0,
#     'nexusKills': 0,
#     'nexusLost': 1,
#     'nexusTakedowns': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'onMyWayPings': 0,
#     'participantId': 10,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5002, 'flex': 5008, 'offense': 5005},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8008, 'var1': 77, 'var2': 13, 'var3': 0},
#         {'perk': 9111, 'var1': 1052, 'var2': 280, 'var3': 0},
#         {'perk': 9104, 'var1': 4, 'var2': 10, 'var3': 0},
#         {'perk': 8017, 'var1': 1086, 'var2': 0, 'var3': 0}],
#        'style': 8000},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8143, 'var1': 347, 'var2': 0, 'var3': 0},
#         {'perk': 8106, 'var1': 5, 'var2': 0, 'var3': 0}],
#        'style': 8100}]},
#     'physicalDamageDealt': 53374,
#     'physicalDamageDealtToChampions': 17922,
#     'physicalDamageTaken': 5648,
#     'profileIcon': 3379,
#     'pushPings': 0,
#     'puuid': 'fp31Ko2pLW9APgmtCdg9X7rdKbPdcw3HcOEXdzlRm-ddyLj27mAE2hQfPyoQ7XQME9Ad9SqPpE2wlg',
#     'quadraKills': 0,
#     'riotIdName': '',
#     'riotIdTagline': '',
#     'role': 'SUPPORT',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 18,
#     'spell2Casts': 21,
#     'spell3Casts': 21,
#     'spell4Casts': 3,
#     'summoner1Casts': 3,
#     'summoner1Id': 4,
#     'summoner2Casts': 4,
#     'summoner2Id': 6,
#     'summonerId': '0BfVmibgMAwiC4rk-CXQ23DX0FMnekJ2jVfa8KMuzbqiILk',
#     'summonerLevel': 332,
#     'summonerName': 'tsablis455',
#     'teamEarlySurrendered': False,
#     'teamId': 200,
#     'teamPosition': '',
#     'timeCCingOthers': 3,
#     'timePlayed': 989,
#     'totalDamageDealt': 65508,
#     'totalDamageDealtToChampions': 20793,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 18259,
#     'totalHeal': 2082,
#     'totalHealsOnTeammates': 0,
#     'totalMinionsKilled': 68,
#     'totalTimeCCDealt': 22,
#     'totalTimeSpentDead': 213,
#     'totalUnitsHealed': 1,
#     'tripleKills': 1,
#     'trueDamageDealt': 4331,
#     'trueDamageDealtToChampions': 1791,
#     'trueDamageTaken': 653,
#     'turretKills': 0,
#     'turretTakedowns': 1,
#     'turretsLost': 4,
#     'unrealKills': 0,
#     'visionClearedPings': 0,
#     'visionScore': 0,
#     'visionWardsBoughtInGame': 0,
#     'wardsKilled': 0,
#     'wardsPlaced': 0,
#     'win': False}],
#   'platformId': 'NA1',
#   'queueId': 450,
#   'teams': [{'bans': [],
#     'objectives': {'baron': {'first': False, 'kills': 0},
#      'champion': {'first': True, 'kills': 60},
#      'dragon': {'first': False, 'kills': 0},
#      'inhibitor': {'first': True, 'kills': 1},
#      'riftHerald': {'first': False, 'kills': 0},
#      'tower': {'first': False, 'kills': 4}},
#     'teamId': 100,
#     'win': True},
#    {'bans': [],
#     'objectives': {'baron': {'first': False, 'kills': 0},
#      'champion': {'first': False, 'kills': 42},
#      'dragon': {'first': False, 'kills': 0},
#      'inhibitor': {'first': False, 'kills': 0},
#      'riftHerald': {'first': False, 'kills': 0},
#      'tower': {'first': True, 'kills': 1}},
#     'teamId': 200,
#     'win': False}],
#   'tournamentCode': ''}}
